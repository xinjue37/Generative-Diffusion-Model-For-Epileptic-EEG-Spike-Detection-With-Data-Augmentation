# %% [markdown]
# ## Import all library

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import mne
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import pywt 
from PIL import Image
from utility import *
from model import *
from torchsummary import summary
import torch.optim.lr_scheduler as lr_scheduler


# total_sample = 6204
# num_spike    = 1535
# ((total_sample-num_spike)*2)/(num_spike*2) = 3.041
LOSS_POS_WEIGHT       = torch.tensor([3.041])

MODEL_FILE_DIRC_SateLight = MODEL_FILE_DIRC + "/SateLight_synthesized"
MODEL_FILE_DIRC_CNN       = MODEL_FILE_DIRC + "/CNN_synthesized"
os.makedirs(MODEL_FILE_DIRC_CNN, exist_ok=True)
os.makedirs(MODEL_FILE_DIRC_SateLight, exist_ok=True)

torch.manual_seed(3407)

# %% [markdown]
# ## Data Preparation
# * Convert the data from csv to Dataloader

# %%
# %%time
eeg_num_list = list(range(1,21))
datasets, datasets_label, datasets_DWT = get_dataloader(eeg_num_list, get_dataloader=False, shuffle=False)
    
train_dataset, valid_dataset, test_dataset = datasets
train_label,   valid_label,   test_label   = datasets_label
train_DWT,     valid_DWT,     test_DWT     = datasets_DWT

# Load the synthesized data and process it (copy from Evaluate Diffusion Model)
df                  = pd.read_csv("synthesized_data.csv")  # Shape=(num_data, num_channel)
synthesized_data = torch.tensor(df.values)
synthesized_data = synthesized_data.view(synthesized_data.shape[0]//(DURATION*NEW_FREQUENCY),-1 , len(AVE_CHANNELS_NAME)) # Shape=(bs, num_signal, num_channel)
synthesized_data = synthesized_data.permute(0,2,1)
synthesized_data = synthesized_data.type(torch.float32) 


# Get the label and data after discrete wavelet transform
synthesized_data_label = train_label[:len(synthesized_data)].clone()
synthesized_data_DWT   = pywt.wavedec(synthesized_data, 'db1')                         # Apply DWT
synthesized_data_DWT   = np.concatenate(synthesized_data_DWT, axis=2, dtype=np.float32)# Concatenate all DWT data
synthesized_data_DWT   = torch.from_numpy(synthesized_data_DWT)

# Concatenate synthesized data and training data
train_dataset = torch.cat([train_dataset, synthesized_data], axis=0) 
train_label   = torch.cat([train_label, synthesized_data_label], axis=0)
train_DWT     = torch.cat([train_DWT, synthesized_data_DWT], axis=0)

print("Number of training data:", train_dataset.shape[0])
print("Number of spike in training data:", (train_label==1).sum())
# Out:
# The data from EEG_csv/eeg1.csv is loaded
# There is spike in this eeg file
# Data before split : (3840, 19)
# Data with   spike: (3840, 19)
# Data after  split into window: (3, 1280, 19)
# Labels: (3,)
# Num spike: 3
# EEG1 has 3 windows of data
#
#
# The data from EEG_csv/eeg2.csv is loaded
# There is no spike in this eeg file
# (160, 1280, 19)
# EEG2 has 160 windows of data
#
#
# The data from EEG_csv/eeg3.csv is loaded
# There is no spike in this eeg file
# (153, 1280, 19)
# EEG3 has 153 windows of data
#
#
# The data from EEG_csv/eeg4.csv is loaded
# There is no spike in this eeg file
# (170, 1280, 19)
# EEG4 has 170 windows of data
#
#
# The data from EEG_csv/eeg5.csv is loaded
# There is no spike in this eeg file
# (148, 1280, 19)
# EEG5 has 148 windows of data
#
#
# The data from EEG_csv/eeg6.csv is loaded
# There is no spike in this eeg file
# (207, 1280, 19)
# EEG6 has 207 windows of data
#
#
# The data from EEG_csv/eeg7.csv is loaded
# There is no spike in this eeg file
# (147, 1280, 19)
# EEG7 has 147 windows of data
#
#
# The data from EEG_csv/eeg8.csv is loaded
# There is spike in this eeg file
# Data before split : (3840, 19)
# Data with   spike: (3840, 19)
# Data after  split into window: (3, 1280, 19)
# Labels: (3,)
# Num spike: 3
# EEG8 has 3 windows of data
#
#
# The data from EEG_csv/eeg9.csv is loaded
# There is spike in this eeg file
# Data before split : (3840, 19)
# Data with   spike: (3840, 19)
# Data after  split into window: (3, 1280, 19)
# Labels: (3,)
# Num spike: 3
# EEG9 has 3 windows of data
#
#
# The data from EEG_csv/eeg10.csv is loaded
# There is no spike in this eeg file
# (109, 1280, 19)
# EEG10 has 109 windows of data
#
#
# The data from EEG_csv/eeg11.csv is loaded
# There is no spike in this eeg file
# (251, 1280, 19)
# EEG11 has 251 windows of data
#
#
# The data from EEG_csv/eeg12.csv is loaded
# There is spike in this eeg file
# Data before split : (34560, 19)
# Data with   spike: (34560, 19)
# Data after  split into window: (27, 1280, 19)
# Labels: (27,)
# Num spike: 27
# EEG12 has 27 windows of data
#
#
# The data from EEG_csv/eeg13.csv is loaded
# There is no spike in this eeg file
# (1101, 1280, 19)
# EEG13 has 1101 windows of data
#
#
# The data from EEG_csv/eeg14.csv is loaded
# There is no spike in this eeg file
# (190, 1280, 19)
# EEG14 has 190 windows of data
#
#
# The data from EEG_csv/eeg15.csv is loaded
# There is spike in this eeg file
# Data before split : (215040, 19)
# Data with   spike: (215040, 19)
# Data after  split into window: (168, 1280, 19)
# Labels: (168,)
# Num spike: 168
# EEG15 has 168 windows of data
#
#
# The data from EEG_csv/eeg16.csv is loaded
# There is no spike in this eeg file
# (89, 1280, 19)
# EEG16 has 89 windows of data
#
#
# The data from EEG_csv/eeg17.csv is loaded
# There is spike in this eeg file
# Data before split : (203520, 19)
# Data with   spike: (203520, 19)
# Data after  split into window: (159, 1280, 19)
# Labels: (159,)
# Num spike: 159
# EEG17 has 159 windows of data
#
#
# The data from EEG_csv/eeg18.csv is loaded
# There is spike in this eeg file
# Data before split : (533760, 19)
# Data with   spike: (533760, 19)
# Data after  split into window: (417, 1280, 19)
# Labels: (417,)
# Num spike: 417
# EEG18 has 417 windows of data
#
#
# The data from EEG_csv/eeg19.csv is loaded
# There is spike in this eeg file
# Data before split : (157440, 19)
# Data with   spike: (157440, 19)
# Data after  split into window: (123, 1280, 19)
# Labels: (123,)
# Num spike: 123
# EEG19 has 123 windows of data
#
#
# The data from EEG_csv/eeg20.csv is loaded
# There is no spike in this eeg file
# (96, 1280, 19)
# EEG20 has 96 windows of data
#
#
# > > > Train    data  has shape: torch.Size([2610, 19, 1280]) when duration = 10 seconds
# > > > Data after DWT has shape: torch.Size([2610, 19, 1282])
# > > > Label              shape: torch.Size([2610])
# Number of training data: 5152
# Number of spike in training data: tensor(1270)
# CPU times: total: 2min 18s
# Wall time: 1min 54s

# %%
# Get the number of data and Place it into dataloader
num_train_data = train_dataset.shape[0]
num_valid_data = valid_dataset.shape[0]
num_test_data  = test_dataset.shape[0]
train_data = DataLoader(dataset = Dataset_Class1(train_dataset, train_label), 
                        batch_size = BATCH_SIZE, shuffle = True, num_workers=1)
valid_data = DataLoader(dataset = Dataset_Class1(valid_dataset, valid_label), 
                        batch_size = BATCH_SIZE, shuffle = True, num_workers=1)
test_data  = DataLoader(dataset = Dataset_Class1(test_dataset, test_label), 
                        batch_size = BATCH_SIZE, shuffle = True, num_workers=1)

# %% [markdown]
# ## Function to train the model

# %%
def load_classification_model_dict(model, MODEL_FILE_DIRC, model_name):
    list_model = os.listdir(MODEL_FILE_DIRC) 
    if len(list_model) > 0:    # Load the latest trained model
        if os.path.exists(f"{MODEL_FILE_DIRC}/{model_name}_best.pt"):
            state_dict_loaded    = torch.load(f"{MODEL_FILE_DIRC}/{model_name}_best.pt")
            prev_best_valid_f1   = state_dict_loaded["valid_f1_score"]
            prev_best_valid_loss = state_dict_loaded["valid_loss"]
        list_model.remove(f"{model_name}_best.pt")
        num_list   = [int(model_dir[model_dir.rindex("_") +1: model_dir.rindex(".")]) for model_dir in list_model if model_dir.endswith(".pt")]
        num_max    = np.max(num_list)
        
        state_dict_loaded = torch.load(f"{MODEL_FILE_DIRC}/{model_name}_{num_max}.pt")
        model.load_state_dict(state_dict_loaded["model"])
        EPOCH_START = state_dict_loaded["epoch"] + 1
        
        print(f"The model has been loaded from the file '{model_name}_{num_max}.pt'")

        if os.path.exists(f"{MODEL_FILE_DIRC}/Loss.csv"):
            df = pd.read_csv(f"{MODEL_FILE_DIRC}/Loss.csv")
            df = df.iloc[:EPOCH_START-1, :]
            print(f"The dataframe that record the loss have been loaded from {MODEL_FILE_DIRC}/Loss.csv")

    else:
        EPOCH_START            = 1
        prev_best_valid_f1     = -1
        prev_best_valid_loss   = 10000
        df                     = pd.DataFrame(columns = ["Train Loss", "Valid Loss"] + \
                                                         flatten_concatenation([[f"Train {metric}", f"Valid {metric}"] for metric in ["precision", "accuracy", "f1_score", "recall"]]) )
    return model, df, EPOCH_START, prev_best_valid_f1, prev_best_valid_loss

def start_classification_model_training(EPOCH_START, NUM_EPOCHS_CLASSIFIER, 
                                        model, MODEL_FILE_DIRC, model_name,  
                                        df, prev_best_valid_f1,prev_best_valid_loss,
                                        train_data, num_train_data, 
                                        valid_data, num_valid_data, 
                                        scheduler, optimizer, device):
    count = 0
    for epoch in range(EPOCH_START, NUM_EPOCHS_CLASSIFIER):
        
            ## 1. Training
            model.train()
            train_loss, train_metric = train_classifier(model, train_data, device, num_train_data, optimizer, LOSS_POS_WEIGHT=torch.tensor([3])) 
            
            ## 2. Evaluating
            model.eval()
            valid_loss, valid_metric = evaluate_classifier(model, valid_data, device, num_valid_data, LOSS_POS_WEIGHT=torch.tensor([3]))  
            
            ## 3. Show the result
            list_data       = [train_loss, valid_loss]
            for key in ["precision", "accuracy", "f1_score", "recall"]:
                list_data.append(train_metric[key])
                list_data.append(valid_metric[key])
            df.loc[len(df)] = list_data
            
            print_log(f"> > > Epoch     : {epoch}", MODEL_FILE_DIRC)
            print_log(f"Train {'loss':<10}: {train_loss}", MODEL_FILE_DIRC)
            print_log(f"Valid {'loss':<10}: {valid_loss}", MODEL_FILE_DIRC)
            for key in ["precision", "accuracy", "f1_score", "recall"]:
                print_log(f"Train {key:<10}: {train_metric[key]}", MODEL_FILE_DIRC)
                print_log(f"Valid {key:<10}: {valid_metric[key]}", MODEL_FILE_DIRC)

            
            ## 3.1 Plot the loss function
            fig,ax = plt.subplots(3,2, figsize=(10,10))
            x_data = range(len(df["Train Loss"]))
            for i, key in enumerate(["Loss","precision", "accuracy", "f1_score", "recall"]):    
                ax[i%3][i//3].plot(x_data, df[f"Train {key}"], label=f"Train {key}")
                ax[i%3][i//3].plot(x_data, df[f"Valid {key}"], label=f"Valid {key}")
                ax[i%3][i//3].legend()
            plt.savefig(f'{MODEL_FILE_DIRC}/Loss.png', transparent=False, facecolor='white')
            plt.close('all')

            ## 3.3. Save model and Stoping criteria
            if prev_best_valid_f1 <= valid_metric["f1_score"]:  # If previous best validation f1-score <= current f1-score 
                state_dict = {
                    "model": model.state_dict(), 
                    "epoch":epoch,
                    "valid_f1_score": valid_metric["f1_score"],
                    "valid_loss": valid_loss
                }
                torch.save(state_dict, f"{MODEL_FILE_DIRC}/{model_name}_best.pt")
                prev_best_valid_f1 = valid_metric["f1_score"]  # Previous validation loss = Current validation loss
                count = 0
            else:
                count += 1
            
            if epoch % 5 == 0:
                state_dict = {
                    "model": model.state_dict(), 
                    "epoch":epoch,
                    "valid_f1_score": valid_metric["f1_score"],
                    "valid_loss": valid_loss
                }
                torch.save(state_dict, f"{MODEL_FILE_DIRC}/{model_name}_{epoch}.pt")
            
            df.to_csv(f"{MODEL_FILE_DIRC}/Loss.csv", index=False)
            
            if count == MAX_COUNT_F1_SCORE:
                print_log(f"The validation f1 score is not increasing for continuous {MAX_COUNT_F1_SCORE} time, so training stop", MODEL_FILE_DIRC)
                break
            
            scheduler.step()

# %% [markdown]
# ## Build and Train the SateLight model

# %% [markdown]
# ### Build the SateLight model

# %%
model      = SateLight().to(device)
optimizer  = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)  
scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)

# Get the following information:
# 1. Previous Trained model (if exist)
# 2. df that store the training/validation loss & metrics
# 3. epoch where the training start
# 4. Previous Highest Validation Recall
# 5. Previous Lowest  Validation Loss
model, df, EPOCH_START, prev_best_valid_f1, prev_best_valid_loss = load_classification_model_dict(model, MODEL_FILE_DIRC_SateLight, "SateLight")

# # Load the previous train model from original data
# state_dict_loaded = torch.load(MODEL_FILE_DIRC + f"/SateLight/SateLight_best.pt")
# model.load_state_dict(state_dict_loaded["model"])

# Get the summary of the model
print(summary(model, (19,1280)))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ├─Sequential: 1-1                             [-1, 32, 1, 641]          --
# |    └─Conv2d: 2-1                            [-1, 16, 19, 641]         10,256
# |    └─Conv2d: 2-2                            [-1, 32, 1, 641]          640
# ├─BatchNorm1d: 1-2                            [-1, 32, 641]             64
# ├─ReLU: 1-3                                   [-1, 32, 641]             --
# ├─Dropout: 1-4                                [-1, 32, 641]             --
# ├─MaxPool1d: 1-5                              [-1, 32, 160]             --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-3                        [-1, 160, 32]             --
# |    |    └─SelfAttention: 3-1                [-1, 160, 32]             7,392
# |    |    └─BatchNorm1d: 3-2                  [-1, 160, 32]             320
# |    |    └─Dropout: 3-3                      [-1, 160, 32]             --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-4                        [-1, 160, 64]             --
# |    |    └─Linear: 3-4                       [-1, 160, 64]             2,112
# |    |    └─BatchNorm1d: 3-5                  [-1, 160, 64]             320
# |    |    └─ReLU: 3-6                         [-1, 160, 64]             --
# |    |    └─Dropout: 3-7                      [-1, 160, 64]             --
# ├─MaxPool1d: 1-6                              [-1, 64, 40]              --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-5                        [-1, 40, 64]              --
# |    |    └─SelfAttention: 3-8                [-1, 40, 64]              29,120
# |    |    └─BatchNorm1d: 3-9                  [-1, 40, 64]              80
# |    |    └─Dropout: 3-10                     [-1, 40, 64]              --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-6                        [-1, 40, 96]              --
# |    |    └─Linear: 3-11                      [-1, 40, 96]              6,240
# |    |    └─BatchNorm1d: 3-12                 [-1, 40, 96]              80
# |    |    └─ReLU: 3-13                        [-1, 40, 96]              --
# |    |    └─Dropout: 3-14                     [-1, 40, 96]              --
# ├─MaxPool1d: 1-7                              [-1, 96, 10]              --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-7                        [-1, 10, 96]              --
# |    |    └─SelfAttention: 3-15               [-1, 10, 96]              65,184
# |    |    └─BatchNorm1d: 3-16                 [-1, 10, 96]              20
# |    |    └─Dropout: 3-17                     [-1, 10, 96]              --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-8                        [-1, 10, 128]             --
# |    |    └─Linear: 3-18                      [-1, 10, 128]             12,416
# |    |    └─BatchNorm1d: 3-19                 [-1, 10, 128]             20
# |    |    └─ReLU: 3-20                        [-1, 10, 128]             --
# |    |    └─Dropout: 3-21                     [-1, 10, 128]             --
# ├─MaxPool1d: 1-8                              [-1, 128, 2]              --
# ├─Linear: 1-9                                 [-1, 1]                   257
# ===============================================================================================
# Total params: 134,521
# Trainable params: 134,521
# Non-trainable params: 0
# Total mult-adds (M): 125.46
# ===============================================================================================
# Input size (MB): 0.09
# Forward/backward pass size (MB): 2.30
# Params size (MB): 0.51
# Estimated Total Size (MB): 2.90
# ===============================================================================================
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ├─Sequential: 1-1                             [-1, 32, 1, 641]          --
# |    └─Conv2d: 2-1                            [-1, 16, 19, 641]         10,256
# |    └─Conv2d: 2-2                            [-1, 32, 1, 641]          640
# ├─BatchNorm1d: 1-2                            [-1, 32, 641]             64
# ├─ReLU: 1-3                                   [-1, 32, 641]             --
# ├─Dropout: 1-4                                [-1, 32, 641]             --
# ├─MaxPool1d: 1-5                              [-1, 32, 160]             --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-3                        [-1, 160, 32]             --
# |    |    └─SelfAttention: 3-1                [-1, 160, 32]             7,392
# |    |    └─BatchNorm1d: 3-2                  [-1, 160, 32]             320
# |    |    └─Dropout: 3-3                      [-1, 160, 32]             --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-4                        [-1, 160, 64]             --
# |    |    └─Linear: 3-4                       [-1, 160, 64]             2,112
# |    |    └─BatchNorm1d: 3-5                  [-1, 160, 64]             320
# |    |    └─ReLU: 3-6                         [-1, 160, 64]             --
# |    |    └─Dropout: 3-7                      [-1, 160, 64]             --
# ├─MaxPool1d: 1-6                              [-1, 64, 40]              --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-5                        [-1, 40, 64]              --
# |    |    └─SelfAttention: 3-8                [-1, 40, 64]              29,120
# |    |    └─BatchNorm1d: 3-9                  [-1, 40, 64]              80
# |    |    └─Dropout: 3-10                     [-1, 40, 64]              --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-6                        [-1, 40, 96]              --
# |    |    └─Linear: 3-11                      [-1, 40, 96]              6,240
# |    |    └─BatchNorm1d: 3-12                 [-1, 40, 96]              80
# |    |    └─ReLU: 3-13                        [-1, 40, 96]              --
# |    |    └─Dropout: 3-14                     [-1, 40, 96]              --
# ├─MaxPool1d: 1-7                              [-1, 96, 10]              --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-7                        [-1, 10, 96]              --
# |    |    └─SelfAttention: 3-15               [-1, 10, 96]              65,184
# |    |    └─BatchNorm1d: 3-16                 [-1, 10, 96]              20
# |    |    └─Dropout: 3-17                     [-1, 10, 96]              --
# ├─ModuleList: 1                               []                        --
# |    └─Sequential: 2-8                        [-1, 10, 128]             --
# |    |    └─Linear: 3-18                      [-1, 10, 128]             12,416
# |    |    └─BatchNorm1d: 3-19                 [-1, 10, 128]             20
# |    |    └─ReLU: 3-20                        [-1, 10, 128]             --
# |    |    └─Dropout: 3-21                     [-1, 10, 128]             --
# ├─MaxPool1d: 1-8                              [-1, 128, 2]              --
# ├─Linear: 1-9                                 [-1, 1]                   257
# ===============================================================================================
# Total params: 134,521
# Trainable params: 134,521
# Non-trainable params: 0
# Total mult-adds (M): 125.46
# ===============================================================================================
# Input size (MB): 0.09
# Forward/backward pass size (MB): 2.30
# Params size (MB): 0.51
# Estimated Total Size (MB): 2.90
# ===============================================================================================

# %% [markdown]
# ### Print out the model info

# %%
seperate = "\n" + "-" * 100 + "\n"
print(seperate + "Model infomation" + seperate)
print(f"Device used        :", device)
print(f"BATCH SIZE         :", BATCH_SIZE)
print(f"MAX_COUNT_F1_SCORE :", MAX_COUNT_F1_SCORE)
print(f"LEARNING RATE      :", LEARNING_RATE)
print(f"Prev Best f1-score in validation dataset:", prev_best_valid_f1)
print(f"Prev Best validation loss             :", prev_best_valid_loss)
print(f"Number of EPOCH for training   :",NUM_EPOCHS_CLASSIFIER, f"(EPOCH start from {EPOCH_START})")
print(f"Num of epochs of data for train:", num_train_data)
print(f"Num of epochs of data for valid:", num_valid_data)
print(f'Model parameters               : {sum(p.numel() for p in model.parameters()):,}' )
# Out:
# ----------------------------------------------------------------------------------------------------
# Model infomation
# ----------------------------------------------------------------------------------------------------
#
# Device used        : cuda
# BATCH SIZE         : 32
# MAX_COUNT_F1_SCORE : 10
# LEARNING RATE      : 0.001
# Prev Best f1-score in validation dataset: -1
# Prev Best validation loss             : 10000
# Number of EPOCH for training   : 101 (EPOCH start from 1)
# Num of epochs of data for train: 5152
# Num of epochs of data for valid: 557
# Model parameters               : 134,521

# %% [markdown]
# ### Start Training Loop

# %%
# %%time
start_classification_model_training(EPOCH_START, NUM_EPOCHS_CLASSIFIER, 
                                    model, MODEL_FILE_DIRC_SateLight, "SateLight",
                                    df, prev_best_valid_f1, prev_best_valid_loss, 
                                    train_data, num_train_data, 
                                    valid_data, num_valid_data, 
                                    scheduler, optimizer, device)
# Out:
# > > > Epoch     : 1
# Train loss      : 0.022834234014847635
# Valid loss      : 0.01330366495267707
# Train precision : 0.5491803278688525
# Valid precision : 0.9622641509433962
# Train accuracy  : 0.7884316770186336
# Valid accuracy  : 0.9353680430879713
# Train f1_score  : 0.6483870967741936
# Valid f1_score  : 0.85
# Train recall    : 0.7913385826771654
# Valid recall    : 0.7611940298507462
# > > > Epoch     : 2
# Train loss      : 0.012326737327836686
# Valid loss      : 0.006221989072738901
# Train precision : 0.8062636562272396
# Valid precision : 0.9407407407407408
# Train accuracy  : 0.9167313664596274
# Valid accuracy  : 0.9730700179533214
# Train f1_score  : 0.8376844494892168
# Valid f1_score  : 0.9442379182156134
# Train recall    : 0.8716535433070867
# Valid recall    : 0.9477611940298507
# > > > Epoch     : 3
# Train loss      : 0.010174882674325108
# Valid loss      : 0.00649497247697314
# Train precision : 0.8554125662376987
# Valid precision : 0.984375
# Train accuracy  : 0.9357531055900621
# Valid accuracy  : 0.9820466786355476
# Train f1_score  : 0.8722500964878426
# Valid f1_score  : 0.9618320610687023
# Train recall    : 0.889763779527559
# Valid recall    : 0.9402985074626866
# > > > Epoch     : 4
# Train loss      : 0.008100857788274608
# Valid loss      : 0.004172737440980529
# Train precision : 0.8889745566692367
# Valid precision : 0.9552238805970149
# Train accuracy  : 0.9493400621118012
# Valid accuracy  : 0.9784560143626571
# Train f1_score  : 0.8983248928710557
# Valid f1_score  : 0.9552238805970149
# Train recall    : 0.9078740157480315
# Valid recall    : 0.9552238805970149
# > > > Epoch     : 5
# Train loss      : 0.008388552208422387
# Valid loss      : 0.005482402697031652
# Train precision : 0.8679104477611941
# Valid precision : 0.968503937007874
# Train accuracy  : 0.9448757763975155
# Valid accuracy  : 0.9730700179533214
# Train f1_score  : 0.8911877394636015
# Valid f1_score  : 0.9425287356321839
# Train recall    : 0.915748031496063
# Valid recall    : 0.917910447761194
# > > > Epoch     : 6
# Train loss      : 0.006880019969843409
# Valid loss      : 0.004595596450289019
# Train precision : 0.899390243902439
# Valid precision : 0.9154929577464789
# Train accuracy  : 0.9569099378881988
# Valid accuracy  : 0.9712746858168761
# Train f1_score  : 0.9140201394268009
# Valid f1_score  : 0.9420289855072463
# Train recall    : 0.9291338582677166
# Valid recall    : 0.9701492537313433
# > > > Epoch     : 7
# Train loss      : 0.006501238199760009
# Valid loss      : 0.004411085368312989
# Train precision : 0.9380952380952381
# Valid precision : 0.9921875
# Train accuracy  : 0.96777950310559
# Valid accuracy  : 0.9856373429084381
# Train f1_score  : 0.9343873517786562
# Valid f1_score  : 0.9694656488549618
# Train recall    : 0.9307086614173228
# Valid recall    : 0.9477611940298507
# > > > Epoch     : 8
# Train loss      : 0.005873530211490405
# Valid loss      : 0.004607794292210944
# Train precision : 0.9186492709132771
# Valid precision : 0.9921875
# Train accuracy  : 0.9652562111801242
# Valid accuracy  : 0.9856373429084381
# Train f1_score  : 0.9304314030314808
# Valid f1_score  : 0.9694656488549618
# Train recall    : 0.9425196850393701
# Valid recall    : 0.9477611940298507
# > > > Epoch     : 9
# Train loss      : 0.005954119118790269
# Valid loss      : 0.0032719570233802607
# Train precision : 0.9313572542901716
# Valid precision : 0.9555555555555556
# Train accuracy  : 0.968167701863354
# Valid accuracy  : 0.9802513464991023
# Train f1_score  : 0.9357366771159875
# Valid f1_score  : 0.9591078066914498
# Train recall    : 0.9401574803149606
# Valid recall    : 0.9626865671641791
# > > > Epoch     : 10
# Train loss      : 0.005730361416076815
# Valid loss      : 0.006832142709127395
# Train precision : 0.9284046692607004
# Valid precision : 0.9841269841269841
# Train accuracy  : 0.9671972049689441
# Valid accuracy  : 0.9784560143626571
# Train f1_score  : 0.9338551859099804
# Valid f1_score  : 0.9538461538461539
# Train recall    : 0.9393700787401574
# Valid recall    : 0.9253731343283582
# > > > Epoch     : 11
# Train loss      : 0.004428337023201036
# Valid loss      : 0.004744607140101105
# Train precision : 0.9380260137719969
# Valid precision : 0.9555555555555556
# Train accuracy  : 0.9757375776397516
# Valid accuracy  : 0.9802513464991023
# Train f1_score  : 0.9514939852541715
# Valid f1_score  : 0.9591078066914498
# Train recall    : 0.9653543307086614
# Valid recall    : 0.9626865671641791
# > > > Epoch     : 12
# Train loss      : 0.003548264684270733
# Valid loss      : 0.006161353834260998
# Train precision : 0.9667721518987342
# Valid precision : 0.9923076923076923
# Train accuracy  : 0.9825310559006211
# Valid accuracy  : 0.9892280071813285
# Train f1_score  : 0.9644830307813733
# Valid f1_score  : 0.9772727272727273
# Train recall    : 0.9622047244094488
# Valid recall    : 0.9626865671641791
# > > > Epoch     : 13
# Train loss      : 0.0025952631450211682
# Valid loss      : 0.006272662408742719
# Train precision : 0.97562893081761
# Valid precision : 0.9921875
# Train accuracy  : 0.9883540372670807
# Valid accuracy  : 0.9856373429084381
# Train f1_score  : 0.97639653815893
# Valid f1_score  : 0.9694656488549618
# Train recall    : 0.9771653543307086
# Valid recall    : 0.9477611940298507
# > > > Epoch     : 14
# Train loss      : 0.0021155573265092265
# Valid loss      : 0.007588741337254316
# Train precision : 0.9704968944099379
# Valid precision : 0.9921875
# Train accuracy  : 0.9887422360248447
# Valid accuracy  : 0.9856373429084381
# Train f1_score  : 0.9773260359655981
# Valid f1_score  : 0.9694656488549618
# Train recall    : 0.984251968503937
# Valid recall    : 0.9477611940298507
# > > > Epoch     : 15
# Train loss      : 0.0021985137976368056
# Valid loss      : 0.006105000480040331
# Train precision : 0.97643362136685
# Valid precision : 0.9774436090225563
# Train accuracy  : 0.9889363354037267
# Valid accuracy  : 0.9874326750448833
# Train f1_score  : 0.9775855289028706
# Valid f1_score  : 0.9737827715355806
# Train recall    : 0.978740157480315
# Valid recall    : 0.9701492537313433
# > > > Epoch     : 16
# Train loss      : 0.002348330224125822
# Valid loss      : 0.007957325467474706
# Train precision : 0.9810725552050473
# Valid precision : 0.9923664122137404
# Train accuracy  : 0.9902950310559007
# Valid accuracy  : 0.9910233393177738
# Train f1_score  : 0.9802994483845547
# Valid f1_score  : 0.9811320754716981
# Train recall    : 0.9795275590551181
# Valid recall    : 0.9701492537313433
# > > > Epoch     : 17
# Train loss      : 0.0022495708990364514
# Valid loss      : 0.01194364975062968
# Train precision : 0.9912767644726408
# Valid precision : 0.9920634920634921
# Train accuracy  : 0.9939829192546584
# Valid accuracy  : 0.9820466786355476
# Train f1_score  : 0.9877518767285658
# Valid f1_score  : 0.9615384615384616
# Train recall    : 0.984251968503937
# Valid recall    : 0.9328358208955224
# > > > Epoch     : 18
# Train loss      : 0.0017527733908081979
# Valid loss      : 0.011108050490077417
# Train precision : 0.9850863422291993
# Valid precision : 0.9836065573770492
# Train accuracy  : 0.9934006211180124
# Valid accuracy  : 0.9712746858168761
# Train f1_score  : 0.9866352201257862
# Valid f1_score  : 0.9375
# Train recall    : 0.9881889763779528
# Valid recall    : 0.8955223880597015
# > > > Epoch     : 19
# Train loss      : 0.0020500342739517043
# Valid loss      : 0.009115530222677751
# Train precision : 0.9881141045958796
# Valid precision : 0.9921875
# Train accuracy  : 0.9926242236024845
# Valid accuracy  : 0.9856373429084381
# Train f1_score  : 0.9849921011058452
# Valid f1_score  : 0.9694656488549618
# Train recall    : 0.9818897637795275
# Valid recall    : 0.9477611940298507
# > > > Epoch     : 20
# Train loss      : 0.0022106326580451294
# Valid loss      : 0.007638199341450391
# Train precision : 0.983477576711251
# Valid precision : 0.9921875
# Train accuracy  : 0.9920419254658385
# Valid accuracy  : 0.9856373429084381
# Train f1_score  : 0.9838646202282566
# Valid f1_score  : 0.9694656488549618
# Train recall    : 0.984251968503937
# Valid recall    : 0.9477611940298507
# > > > Epoch     : 21
# Train loss      : 0.0014305580323541428
# Valid loss      : 0.007502464923248551
# Train precision : 0.992862807295797
# Valid precision : 0.9629629629629629
# Train accuracy  : 0.9947593167701864
# Valid accuracy  : 0.9838420107719928
# Train f1_score  : 0.9893322797313315
# Valid f1_score  : 0.966542750929368
# Train recall    : 0.9858267716535433
# Valid recall    : 0.9701492537313433
# > > > Epoch     : 22
# Train loss      : 0.001036562258025048
# Valid loss      : 0.008449450265349176
# Train precision : 0.9928909952606635
# Valid precision : 0.9770992366412213
# Train accuracy  : 0.9957298136645962
# Valid accuracy  : 0.9838420107719928
# Train f1_score  : 0.9913249211356467
# Valid f1_score  : 0.9660377358490566
# Train recall    : 0.989763779527559
# Valid recall    : 0.9552238805970149
# > > > Epoch     : 23
# Train loss      : 0.0007306688487042803
# Valid loss      : 0.010055068320741958
# Train precision : 0.9936858721389108
# Valid precision : 0.9696969696969697
# Train accuracy  : 0.9963121118012422
# Valid accuracy  : 0.9820466786355476
# Train f1_score  : 0.9925108395743003
# Valid f1_score  : 0.9624060150375939
# Train recall    : 0.9913385826771653
# Valid recall    : 0.9552238805970149
# > > > Epoch     : 24
# Train loss      : 0.0012275834787471244
# Valid loss      : 0.00899919451697852
# Train precision : 0.986697965571205
# Valid precision : 0.9699248120300752
# Train accuracy  : 0.9949534161490683
# Valid accuracy  : 0.9838420107719928
# Train f1_score  : 0.9897959183673469
# Valid f1_score  : 0.9662921348314607
# Train recall    : 0.9929133858267717
# Valid recall    : 0.9626865671641791
# > > > Epoch     : 25
# Train loss      : 0.0009291952091826354
# Valid loss      : 0.007083751927913494
# Train precision : 0.9889937106918238
# Valid precision : 0.9772727272727273
# Train accuracy  : 0.9949534161490683
# Valid accuracy  : 0.9856373429084381
# Train f1_score  : 0.989771833202203
# Valid f1_score  : 0.9699248120300752
# Train recall    : 0.9905511811023622
# Valid recall    : 0.9626865671641791
# > > > Epoch     : 26
# Train loss      : 0.0008427319058874561
# Valid loss      : 0.008811533326827345
# Train precision : 0.991345397324941
# Valid precision : 0.9699248120300752
# Train accuracy  : 0.9959239130434783
# Valid accuracy  : 0.9838420107719928
# Train f1_score  : 0.9917355371900827
# Valid f1_score  : 0.9662921348314607
# Train recall    : 0.9921259842519685
# Valid recall    : 0.9626865671641791
# The validation f1 score is not increasing for continuous 10 time, so training stop
# CPU times: total: 6min 37s
# Wall time: 10min 14s

# %% [markdown]
# ### Test the model performance on testing dataset

# %%
# Load the best model and turn to evaluation mode
model.eval()
state_dict_loaded = torch.load(f"{MODEL_FILE_DIRC_SateLight}/SateLight_best.pt")
model.load_state_dict(state_dict_loaded["model"])

test_loss, test_metric = evaluate_classifier(model, test_data, device, num_test_data, LOSS_POS_WEIGHT=torch.tensor([3])) 

print("Best model is at epoch:",state_dict_loaded["epoch"])
print("Metric on testing dataset:")
for key, value in test_metric.items():
    print(f"{key:<10}: {value:.4f}")
# Out:
# Best model is at epoch: 16
# Metric on testing dataset:
# precision : 0.9197
# accuracy  : 0.9659
# f1_score  : 0.9299
# recall    : 0.9403

# %% [markdown]
# ## Build and Train the Simple CNN model

# %% [markdown]
# ### Build the CNN model

# %%
model      = CNN().to(device)
optimizer  = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)  
scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)

# Get the following information:
# 1. Previous Trained model (if exist)
# 2. df that store the training/validation loss & metrics
# 3. epoch where the training start
# 4. Previous Highest Validation Recall
# 5. Previous Lowest  Validation Loss
model, df, EPOCH_START, prev_best_valid_f1, prev_best_valid_loss = load_classification_model_dict(model, MODEL_FILE_DIRC_CNN, "CNN")

# # Load the previous train model from original data
# state_dict_loaded = torch.load(MODEL_FILE_DIRC + f"/CNN/CNN_best.pt")
# model.load_state_dict(state_dict_loaded["model"])

# Get the summary of the model
print(summary(model, (19,1280)))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ├─Sequential: 1-1                             [-1, 128, 8]              --
# |    └─Conv1dWithInitialization: 2-1          [-1, 128, 1278]           --
# |    |    └─Conv1d: 3-1                       [-1, 128, 1278]           7,424
# |    └─BatchNorm1d: 2-2                       [-1, 128, 1278]           256
# |    └─ReLU: 2-3                              [-1, 128, 1278]           --
# |    └─MaxPool1d: 2-4                         [-1, 128, 639]            --
# |    └─Conv1dWithInitialization: 2-5          [-1, 64, 637]             --
# |    |    └─Conv1d: 3-2                       [-1, 64, 637]             24,640
# |    └─BatchNorm1d: 2-6                       [-1, 64, 637]             128
# |    └─ReLU: 2-7                              [-1, 64, 637]             --
# |    └─MaxPool1d: 2-8                         [-1, 64, 318]             --
# |    └─Conv1dWithInitialization: 2-9          [-1, 32, 316]             --
# |    |    └─Conv1d: 3-3                       [-1, 32, 316]             6,176
# |    └─BatchNorm1d: 2-10                      [-1, 32, 316]             64
# |    └─ReLU: 2-11                             [-1, 32, 316]             --
# |    └─MaxPool1d: 2-12                        [-1, 32, 158]             --
# |    └─Conv1dWithInitialization: 2-13         [-1, 16, 156]             --
# |    |    └─Conv1d: 3-4                       [-1, 16, 156]             1,552
# |    └─BatchNorm1d: 2-14                      [-1, 16, 156]             32
# |    └─ReLU: 2-15                             [-1, 16, 156]             --
# |    └─MaxPool1d: 2-16                        [-1, 16, 78]              --
# |    └─Conv1dWithInitialization: 2-17         [-1, 32, 76]              --
# |    |    └─Conv1d: 3-5                       [-1, 32, 76]              1,568
# |    └─BatchNorm1d: 2-18                      [-1, 32, 76]              64
# |    └─ReLU: 2-19                             [-1, 32, 76]              --
# |    └─MaxPool1d: 2-20                        [-1, 32, 38]              --
# |    └─Conv1dWithInitialization: 2-21         [-1, 64, 36]              --
# |    |    └─Conv1d: 3-6                       [-1, 64, 36]              6,208
# |    └─BatchNorm1d: 2-22                      [-1, 64, 36]              128
# |    └─ReLU: 2-23                             [-1, 64, 36]              --
# |    └─MaxPool1d: 2-24                        [-1, 64, 18]              --
# |    └─Conv1dWithInitialization: 2-25         [-1, 128, 16]             --
# |    |    └─Conv1d: 3-7                       [-1, 128, 16]             24,704
# |    └─BatchNorm1d: 2-26                      [-1, 128, 16]             256
# |    └─ReLU: 2-27                             [-1, 128, 16]             --
# |    └─MaxPool1d: 2-28                        [-1, 128, 8]              --
# ├─Linear: 1-2                                 [-1, 1]                   1,025
# ===============================================================================================
# Total params: 74,225
# Trainable params: 74,225
# Non-trainable params: 0
# Total mult-adds (M): 28.04
# ===============================================================================================
# Input size (MB): 0.09
# Forward/backward pass size (MB): 3.41
# Params size (MB): 0.28
# Estimated Total Size (MB): 3.79
# ===============================================================================================
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ├─Sequential: 1-1                             [-1, 128, 8]              --
# |    └─Conv1dWithInitialization: 2-1          [-1, 128, 1278]           --
# |    |    └─Conv1d: 3-1                       [-1, 128, 1278]           7,424
# |    └─BatchNorm1d: 2-2                       [-1, 128, 1278]           256
# |    └─ReLU: 2-3                              [-1, 128, 1278]           --
# |    └─MaxPool1d: 2-4                         [-1, 128, 639]            --
# |    └─Conv1dWithInitialization: 2-5          [-1, 64, 637]             --
# |    |    └─Conv1d: 3-2                       [-1, 64, 637]             24,640
# |    └─BatchNorm1d: 2-6                       [-1, 64, 637]             128
# |    └─ReLU: 2-7                              [-1, 64, 637]             --
# |    └─MaxPool1d: 2-8                         [-1, 64, 318]             --
# |    └─Conv1dWithInitialization: 2-9          [-1, 32, 316]             --
# |    |    └─Conv1d: 3-3                       [-1, 32, 316]             6,176
# |    └─BatchNorm1d: 2-10                      [-1, 32, 316]             64
# |    └─ReLU: 2-11                             [-1, 32, 316]             --
# |    └─MaxPool1d: 2-12                        [-1, 32, 158]             --
# |    └─Conv1dWithInitialization: 2-13         [-1, 16, 156]             --
# |    |    └─Conv1d: 3-4                       [-1, 16, 156]             1,552
# |    └─BatchNorm1d: 2-14                      [-1, 16, 156]             32
# |    └─ReLU: 2-15                             [-1, 16, 156]             --
# |    └─MaxPool1d: 2-16                        [-1, 16, 78]              --
# |    └─Conv1dWithInitialization: 2-17         [-1, 32, 76]              --
# |    |    └─Conv1d: 3-5                       [-1, 32, 76]              1,568
# |    └─BatchNorm1d: 2-18                      [-1, 32, 76]              64
# |    └─ReLU: 2-19                             [-1, 32, 76]              --
# |    └─MaxPool1d: 2-20                        [-1, 32, 38]              --
# |    └─Conv1dWithInitialization: 2-21         [-1, 64, 36]              --
# |    |    └─Conv1d: 3-6                       [-1, 64, 36]              6,208
# |    └─BatchNorm1d: 2-22                      [-1, 64, 36]              128
# |    └─ReLU: 2-23                             [-1, 64, 36]              --
# |    └─MaxPool1d: 2-24                        [-1, 64, 18]              --
# |    └─Conv1dWithInitialization: 2-25         [-1, 128, 16]             --
# |    |    └─Conv1d: 3-7                       [-1, 128, 16]             24,704
# |    └─BatchNorm1d: 2-26                      [-1, 128, 16]             256
# |    └─ReLU: 2-27                             [-1, 128, 16]             --
# |    └─MaxPool1d: 2-28                        [-1, 128, 8]              --
# ├─Linear: 1-2                                 [-1, 1]                   1,025
# ===============================================================================================
# Total params: 74,225
# Trainable params: 74,225
# Non-trainable params: 0
# Total mult-adds (M): 28.04
# ===============================================================================================
# Input size (MB): 0.09
# Forward/backward pass size (MB): 3.41
# Params size (MB): 0.28
# Estimated Total Size (MB): 3.79
# ===============================================================================================

# %% [markdown]
# ### Print out the model info

# %%
seperate = "\n" + "-" * 100 + "\n"
print(seperate + "Model infomation" + seperate)
print(f"Device used        :", device)
print(f"BATCH SIZE         :", BATCH_SIZE)
print(f"MAX_COUNT_F1_SCORE :", MAX_COUNT_F1_SCORE)
print(f"LEARNING RATE      :", LEARNING_RATE)
print(f"Prev Best recall in validation dataset:", prev_best_valid_f1)
print(f"Prev Best validation loss             :", prev_best_valid_loss)
print(f"Number of EPOCH for training   :",NUM_EPOCHS_CLASSIFIER, f"(EPOCH start from {EPOCH_START})")
print(f"Num of epochs of data for train:", num_train_data)
print(f"Num of epochs of data for valid:", num_valid_data)
print(f'Model parameters               : {sum(p.numel() for p in model.parameters()):,}' )
# Out:
# ----------------------------------------------------------------------------------------------------
# Model infomation
# ----------------------------------------------------------------------------------------------------
#
# Device used        : cuda
# BATCH SIZE         : 32
# MAX_COUNT_F1_SCORE : 10
# LEARNING RATE      : 0.001
# Prev Best recall in validation dataset: -1
# Prev Best validation loss             : 10000
# Number of EPOCH for training   : 101 (EPOCH start from 1)
# Num of epochs of data for train: 5152
# Num of epochs of data for valid: 557
# Model parameters               : 74,225

# %% [markdown]
# ### Start Training Loop

# %%
# %%time
start_classification_model_training(EPOCH_START, NUM_EPOCHS_CLASSIFIER, 
                                    model, MODEL_FILE_DIRC_CNN, "CNN",
                                    df, prev_best_valid_f1, prev_best_valid_loss, 
                                    train_data, num_train_data, 
                                    valid_data, num_valid_data, 
                                    scheduler, optimizer, device)
# Out:
# > > > Epoch     : 1
# Train loss      : 0.02110473745971085
# Valid loss      : 0.009032030481196392
# Train precision : 0.5571677307022634
# Valid precision : 0.7344632768361582
# Train accuracy  : 0.7917313664596274
# Valid accuracy  : 0.9084380610412927
# Train f1_score  : 0.6414968259271634
# Valid f1_score  : 0.8360128617363344
# Train recall    : 0.7559055118110236
# Valid recall    : 0.9701492537313433
# > > > Epoch     : 2
# Train loss      : 0.008710967061205287
# Valid loss      : 0.0051763932717231705
# Train precision : 0.8756674294431731
# Valid precision : 0.9618320610687023
# Train accuracy  : 0.9446816770186336
# Valid accuracy  : 0.9766606822262118
# Train f1_score  : 0.8895776830685781
# Valid f1_score  : 0.9509433962264151
# Train recall    : 0.9039370078740158
# Valid recall    : 0.9402985074626866
# > > > Epoch     : 3
# Train loss      : 0.0059012600201939856
# Valid loss      : 0.0029768781682988042
# Train precision : 0.9083269671504965
# Valid precision : 0.9692307692307692
# Train accuracy  : 0.9609860248447205
# Valid accuracy  : 0.9784560143626571
# Train f1_score  : 0.922062815044591
# Valid f1_score  : 0.9545454545454546
# Train recall    : 0.9362204724409449
# Valid recall    : 0.9402985074626866
# > > > Epoch     : 4
# Train loss      : 0.0031448682851569513
# Valid loss      : 0.00620834310447105
# Train precision : 0.9556765163297045
# Valid precision : 0.9920634920634921
# Train accuracy  : 0.9809782608695652
# Valid accuracy  : 0.9820466786355476
# Train f1_score  : 0.9616588419405321
# Valid f1_score  : 0.9615384615384616
# Train recall    : 0.9677165354330709
# Valid recall    : 0.9328358208955224
# > > > Epoch     : 5
# Train loss      : 0.002306780077639775
# Valid loss      : 0.007704733342560981
# Train precision : 0.9672131147540983
# Valid precision : 0.991869918699187
# Train accuracy  : 0.9858307453416149
# Valid accuracy  : 0.9766606822262118
# Train f1_score  : 0.9713837710701686
# Valid f1_score  : 0.9494163424124513
# Train recall    : 0.9755905511811024
# Valid recall    : 0.9104477611940298
# > > > Epoch     : 6
# Train loss      : 0.0018732898666339736
# Valid loss      : 0.0048814690947746675
# Train precision : 0.9780392156862745
# Valid precision : 0.8958333333333334
# Train accuracy  : 0.9901009316770186
# Valid accuracy  : 0.9640933572710951
# Train f1_score  : 0.9799607072691552
# Valid f1_score  : 0.9280575539568345
# Train recall    : 0.9818897637795275
# Valid recall    : 0.9626865671641791
# > > > Epoch     : 7
# Train loss      : 0.0014922583920136936
# Valid loss      : 0.0016154597137274665
# Train precision : 0.9880952380952381
# Valid precision : 0.9637681159420289
# Train accuracy  : 0.9922360248447205
# Valid accuracy  : 0.9892280071813285
# Train f1_score  : 0.9841897233201581
# Valid f1_score  : 0.9779411764705882
# Train recall    : 0.9803149606299213
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 8
# Train loss      : 0.0014413728072241662
# Valid loss      : 0.006235890491753549
# Train precision : 0.9857932123125493
# Valid precision : 0.8072289156626506
# Train accuracy  : 0.9924301242236024
# Valid accuracy  : 0.9425493716337523
# Train f1_score  : 0.984627512810406
# Valid f1_score  : 0.8933333333333333
# Train recall    : 0.9834645669291339
# Valid recall    : 1.0
# > > > Epoch     : 9
# Train loss      : 0.001710755728426241
# Valid loss      : 0.0049632546965106385
# Train precision : 0.9834645669291339
# Valid precision : 0.9103448275862069
# Train accuracy  : 0.9918478260869565
# Valid accuracy  : 0.9730700179533214
# Train f1_score  : 0.9834645669291339
# Valid f1_score  : 0.946236559139785
# Train recall    : 0.9834645669291339
# Valid recall    : 0.9850746268656716
# > > > Epoch     : 10
# Train loss      : 0.0011406306189799577
# Valid loss      : 0.002732842771620264
# Train precision : 0.988976377952756
# Valid precision : 0.9847328244274809
# Train accuracy  : 0.9945652173913043
# Valid accuracy  : 0.9874326750448833
# Train f1_score  : 0.988976377952756
# Valid f1_score  : 0.9735849056603774
# Train recall    : 0.988976377952756
# Valid recall    : 0.9626865671641791
# > > > Epoch     : 11
# Train loss      : 0.0003903547820498868
# Valid loss      : 0.0008333295744192416
# Train precision : 0.9976303317535545
# Valid precision : 0.9924812030075187
# Train accuracy  : 0.9980590062111802
# Valid accuracy  : 0.9946140035906643
# Train f1_score  : 0.9960567823343849
# Valid f1_score  : 0.9887640449438202
# Train recall    : 0.9944881889763779
# Valid recall    : 0.9850746268656716
# > > > Epoch     : 12
# Train loss      : 0.00021928962988915362
# Valid loss      : 0.0028642949990214744
# Train precision : 0.9968503937007874
# Valid precision : 0.9923664122137404
# Train accuracy  : 0.9984472049689441
# Valid accuracy  : 0.9910233393177738
# Train f1_score  : 0.9968503937007874
# Valid f1_score  : 0.9811320754716981
# Train recall    : 0.9968503937007874
# Valid recall    : 0.9701492537313433
# > > > Epoch     : 13
# Train loss      : 0.00017651243626460377
# Valid loss      : 0.0019724692231336202
# Train precision : 0.9976377952755906
# Valid precision : 0.9924242424242424
# Train accuracy  : 0.9988354037267081
# Valid accuracy  : 0.992818671454219
# Train f1_score  : 0.9976377952755906
# Valid f1_score  : 0.9849624060150376
# Train recall    : 0.9976377952755906
# Valid recall    : 0.9776119402985075
# > > > Epoch     : 14
# Train loss      : 9.245817932585046e-05
# Valid loss      : 0.0023554329801076202
# Train precision : 1.0
# Valid precision : 0.9924242424242424
# Train accuracy  : 0.999805900621118
# Valid accuracy  : 0.992818671454219
# Train f1_score  : 0.9996061441512406
# Valid f1_score  : 0.9849624060150376
# Train recall    : 0.9992125984251968
# Valid recall    : 0.9776119402985075
# > > > Epoch     : 15
# Train loss      : 0.00010534170632564186
# Valid loss      : 0.0021735622824863173
# Train precision : 0.998426435877262
# Valid precision : 0.9924242424242424
# Train accuracy  : 0.999417701863354
# Valid accuracy  : 0.992818671454219
# Train f1_score  : 0.9988193624557261
# Valid f1_score  : 0.9849624060150376
# Train recall    : 0.9992125984251968
# Valid recall    : 0.9776119402985075
# > > > Epoch     : 16
# Train loss      : 0.00016958527415299055
# Valid loss      : 0.0020265041678562143
# Train precision : 0.9960753532182104
# Valid precision : 0.9924812030075187
# Train accuracy  : 0.9988354037267081
# Valid accuracy  : 0.9946140035906643
# Train f1_score  : 0.9976415094339622
# Valid f1_score  : 0.9887640449438202
# Train recall    : 0.9992125984251968
# Valid recall    : 0.9850746268656716
# > > > Epoch     : 17
# Train loss      : 9.567601784096096e-05
# Valid loss      : 0.004761101664191768
# Train precision : 0.9976415094339622
# Valid precision : 0.9922480620155039
# Train accuracy  : 0.9992236024844721
# Valid accuracy  : 0.9874326750448833
# Train f1_score  : 0.998426435877262
# Valid f1_score  : 0.973384030418251
# Train recall    : 0.9992125984251968
# Valid recall    : 0.9552238805970149
# > > > Epoch     : 18
# Train loss      : 0.00029972138448295326
# Valid loss      : 0.005071794301886855
# Train precision : 0.9968553459119497
# Valid precision : 1.0
# Train accuracy  : 0.9988354037267081
# Valid accuracy  : 0.9892280071813285
# Train f1_score  : 0.997639653815893
# Valid f1_score  : 0.9770992366412213
# Train recall    : 0.9984251968503937
# Valid recall    : 0.9552238805970149
# > > > Epoch     : 19
# Train loss      : 0.00011523756831232294
# Valid loss      : 0.0011682050489466266
# Train precision : 0.9968578161822467
# Valid precision : 0.9637681159420289
# Train accuracy  : 0.99902950310559
# Valid accuracy  : 0.9892280071813285
# Train f1_score  : 0.9980338183248132
# Valid f1_score  : 0.9779411764705882
# Train recall    : 0.9992125984251968
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 20
# Train loss      : 0.00022007391483558415
# Valid loss      : 0.0015619233386810322
# Train precision : 0.998422712933754
# Valid precision : 0.9851851851851852
# Train accuracy  : 0.9988354037267081
# Valid accuracy  : 0.9946140035906643
# Train f1_score  : 0.9976359338061466
# Valid f1_score  : 0.9888475836431226
# Train recall    : 0.9968503937007874
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 21
# Train loss      : 0.00022408621613488895
# Valid loss      : 0.0017783269151601102
# Train precision : 0.997639653815893
# Valid precision : 0.9924812030075187
# Train accuracy  : 0.99902950310559
# Valid accuracy  : 0.9946140035906643
# Train f1_score  : 0.9980322707595435
# Valid f1_score  : 0.9887640449438202
# Train recall    : 0.9984251968503937
# Valid recall    : 0.9850746268656716
# > > > Epoch     : 22
# Train loss      : 2.149424954787866e-05
# Valid loss      : 0.0015913501964553213
# Train precision : 0.999213217938631
# Valid precision : 0.9924812030075187
# Train accuracy  : 0.999805900621118
# Valid accuracy  : 0.9946140035906643
# Train f1_score  : 0.9996064541519087
# Valid f1_score  : 0.9887640449438202
# Train recall    : 1.0
# Valid recall    : 0.9850746268656716
# > > > Epoch     : 23
# Train loss      : 7.706698892478406e-06
# Valid loss      : 0.0016718447269721138
# Train precision : 1.0
# Valid precision : 0.9925373134328358
# Train accuracy  : 1.0
# Valid accuracy  : 0.9964093357271095
# Train f1_score  : 1.0
# Valid f1_score  : 0.9925373134328358
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 24
# Train loss      : 3.610645127438556e-05
# Valid loss      : 0.0018390487511686952
# Train precision : 1.0
# Valid precision : 0.9849624060150376
# Train accuracy  : 1.0
# Valid accuracy  : 0.9910233393177738
# Train f1_score  : 1.0
# Valid f1_score  : 0.9812734082397003
# Train recall    : 1.0
# Valid recall    : 0.9776119402985075
# > > > Epoch     : 25
# Train loss      : 1.380878410416073e-05
# Valid loss      : 0.0016743056768803658
# Train precision : 1.0
# Valid precision : 0.9851851851851852
# Train accuracy  : 1.0
# Valid accuracy  : 0.9946140035906643
# Train f1_score  : 1.0
# Valid f1_score  : 0.9888475836431226
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 26
# Train loss      : 8.305119583504966e-06
# Valid loss      : 0.0049710686123314194
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9874326750448833
# Train f1_score  : 1.0
# Valid f1_score  : 0.9731800766283525
# Train recall    : 1.0
# Valid recall    : 0.9477611940298507
# > > > Epoch     : 27
# Train loss      : 1.42437091329391e-05
# Valid loss      : 0.0017508171420565469
# Train precision : 0.999213217938631
# Valid precision : 0.9925373134328358
# Train accuracy  : 0.999805900621118
# Valid accuracy  : 0.9964093357271095
# Train f1_score  : 0.9996064541519087
# Valid f1_score  : 0.9925373134328358
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 28
# Train loss      : 9.203350006281792e-06
# Valid loss      : 0.002623497339179399
# Train precision : 1.0
# Valid precision : 0.9924242424242424
# Train accuracy  : 1.0
# Valid accuracy  : 0.992818671454219
# Train f1_score  : 1.0
# Valid f1_score  : 0.9849624060150376
# Train recall    : 1.0
# Valid recall    : 0.9776119402985075
# > > > Epoch     : 29
# Train loss      : 3.0185423330186328e-05
# Valid loss      : 0.0021201244093050783
# Train precision : 0.999213217938631
# Valid precision : 0.9708029197080292
# Train accuracy  : 0.999805900621118
# Valid accuracy  : 0.9910233393177738
# Train f1_score  : 0.9996064541519087
# Valid f1_score  : 0.981549815498155
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 30
# Train loss      : 4.8045095030843795e-06
# Valid loss      : 0.0018875826904729677
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9982046678635548
# Train f1_score  : 1.0
# Valid f1_score  : 0.9962546816479401
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 31
# Train loss      : 2.723789526652879e-05
# Valid loss      : 0.002263420040183174
# Train precision : 0.9984276729559748
# Valid precision : 1.0
# Train accuracy  : 0.999611801242236
# Valid accuracy  : 0.9964093357271095
# Train f1_score  : 0.999213217938631
# Valid f1_score  : 0.9924812030075187
# Train recall    : 1.0
# Valid recall    : 0.9850746268656716
# > > > Epoch     : 32
# Train loss      : 0.00010068037083704016
# Valid loss      : 0.002254785169765442
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 0.999417701863354
# Valid accuracy  : 0.9946140035906643
# Train f1_score  : 0.9988175009854159
# Valid f1_score  : 0.9886792452830189
# Train recall    : 0.9976377952755906
# Valid recall    : 0.9776119402985075
# > > > Epoch     : 33
# Train loss      : 7.58330666526954e-06
# Valid loss      : 0.0020193694333530245
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9982046678635548
# Train f1_score  : 1.0
# Valid f1_score  : 0.9962546816479401
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 34
# Train loss      : 2.2161393936164065e-06
# Valid loss      : 0.001752867507053503
# Train precision : 1.0
# Valid precision : 0.9925373134328358
# Train accuracy  : 1.0
# Valid accuracy  : 0.9964093357271095
# Train f1_score  : 1.0
# Valid f1_score  : 0.9925373134328358
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 35
# Train loss      : 0.00011188400339432828
# Valid loss      : 0.001870723732491297
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 0.999805900621118
# Valid accuracy  : 0.9982046678635548
# Train f1_score  : 0.9996061441512406
# Valid f1_score  : 0.9962546816479401
# Train recall    : 0.9992125984251968
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 36
# Train loss      : 0.0002595630498799331
# Valid loss      : 0.001934726532249973
# Train precision : 0.998422712933754
# Valid precision : 0.9925373134328358
# Train accuracy  : 0.9988354037267081
# Valid accuracy  : 0.9964093357271095
# Train f1_score  : 0.9976359338061466
# Valid f1_score  : 0.9925373134328358
# Train recall    : 0.9968503937007874
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 37
# Train loss      : 1.3274703420140258e-05
# Valid loss      : 0.002139093388256519
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9982046678635548
# Train f1_score  : 1.0
# Valid f1_score  : 0.9962546816479401
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 38
# Train loss      : 1.0705452042152935e-05
# Valid loss      : 0.0024401099564304034
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9964093357271095
# Train f1_score  : 1.0
# Valid f1_score  : 0.9924812030075187
# Train recall    : 1.0
# Valid recall    : 0.9850746268656716
# > > > Epoch     : 39
# Train loss      : 1.2140898969816835e-05
# Valid loss      : 0.0024300944991217104
# Train precision : 1.0
# Valid precision : 0.9708029197080292
# Train accuracy  : 1.0
# Valid accuracy  : 0.9910233393177738
# Train f1_score  : 1.0
# Valid f1_score  : 0.981549815498155
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 40
# Train loss      : 7.298359208318327e-06
# Valid loss      : 0.0011380491364075193
# Train precision : 1.0
# Valid precision : 0.9925373134328358
# Train accuracy  : 1.0
# Valid accuracy  : 0.9964093357271095
# Train f1_score  : 1.0
# Valid f1_score  : 0.9925373134328358
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 41
# Train loss      : 1.0276274871688786e-05
# Valid loss      : 0.0019375321111019166
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9964093357271095
# Train f1_score  : 1.0
# Valid f1_score  : 0.9924812030075187
# Train recall    : 1.0
# Valid recall    : 0.9850746268656716
# > > > Epoch     : 42
# Train loss      : 5.7365946209152824e-06
# Valid loss      : 0.002386379380156183
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9946140035906643
# Train f1_score  : 1.0
# Valid f1_score  : 0.9886792452830189
# Train recall    : 1.0
# Valid recall    : 0.9776119402985075
# > > > Epoch     : 43
# Train loss      : 3.908180663784846e-06
# Valid loss      : 0.0017712215326171669
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9982046678635548
# Train f1_score  : 1.0
# Valid f1_score  : 0.9962546816479401
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 44
# Train loss      : 2.3549632247306824e-05
# Valid loss      : 0.0016194998004629689
# Train precision : 1.0
# Valid precision : 0.9925373134328358
# Train accuracy  : 1.0
# Valid accuracy  : 0.9964093357271095
# Train f1_score  : 1.0
# Valid f1_score  : 0.9925373134328358
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 45
# Train loss      : 2.434318704285963e-06
# Valid loss      : 0.0015303141562213744
# Train precision : 1.0
# Valid precision : 0.9779411764705882
# Train accuracy  : 1.0
# Valid accuracy  : 0.992818671454219
# Train f1_score  : 1.0
# Valid f1_score  : 0.9851851851851852
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 46
# Train loss      : 5.117866131532227e-06
# Valid loss      : 0.001837314304272065
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9982046678635548
# Train f1_score  : 1.0
# Valid f1_score  : 0.9962546816479401
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 47
# Train loss      : 2.5029834498960355e-06
# Valid loss      : 0.0021447548675084887
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9982046678635548
# Train f1_score  : 1.0
# Valid f1_score  : 0.9962546816479401
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 48
# Train loss      : 3.7151168578436858e-06
# Valid loss      : 0.0020971334370400102
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9964093357271095
# Train f1_score  : 1.0
# Valid f1_score  : 0.9924812030075187
# Train recall    : 1.0
# Valid recall    : 0.9850746268656716
# > > > Epoch     : 49
# Train loss      : 9.879767167510755e-06
# Valid loss      : 0.0026680516079251064
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.992818671454219
# Train f1_score  : 1.0
# Valid f1_score  : 0.9848484848484849
# Train recall    : 1.0
# Valid recall    : 0.9701492537313433
# > > > Epoch     : 50
# Train loss      : 1.4148434716977277e-06
# Valid loss      : 0.0026612450146557107
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.992818671454219
# Train f1_score  : 1.0
# Valid f1_score  : 0.9848484848484849
# Train recall    : 1.0
# Valid recall    : 0.9701492537313433
# > > > Epoch     : 51
# Train loss      : 1.4035846800520206e-06
# Valid loss      : 0.0023921736802960344
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9946140035906643
# Train f1_score  : 1.0
# Valid f1_score  : 0.9886792452830189
# Train recall    : 1.0
# Valid recall    : 0.9776119402985075
# > > > Epoch     : 52
# Train loss      : 1.178266388571197e-06
# Valid loss      : 0.0035096038817840377
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.992818671454219
# Train f1_score  : 1.0
# Valid f1_score  : 0.9848484848484849
# Train recall    : 1.0
# Valid recall    : 0.9701492537313433
# > > > Epoch     : 53
# Train loss      : 1.686447787435204e-06
# Valid loss      : 0.0027311439459693195
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9946140035906643
# Train f1_score  : 1.0
# Valid f1_score  : 0.9886792452830189
# Train recall    : 1.0
# Valid recall    : 0.9776119402985075
# > > > Epoch     : 54
# Train loss      : 4.965001892483042e-06
# Valid loss      : 0.002634932962370662
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.992818671454219
# Train f1_score  : 1.0
# Valid f1_score  : 0.9848484848484849
# Train recall    : 1.0
# Valid recall    : 0.9701492537313433
# > > > Epoch     : 55
# Train loss      : 2.4955515760644754e-05
# Valid loss      : 0.002478007539388692
# Train precision : 0.999213217938631
# Valid precision : 1.0
# Train accuracy  : 0.999805900621118
# Valid accuracy  : 0.9964093357271095
# Train f1_score  : 0.9996064541519087
# Valid f1_score  : 0.9924812030075187
# Train recall    : 1.0
# Valid recall    : 0.9850746268656716
# > > > Epoch     : 56
# Train loss      : 9.25280076484915e-07
# Valid loss      : 0.0022279458952406167
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9982046678635548
# Train f1_score  : 1.0
# Valid f1_score  : 0.9962546816479401
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 57
# Train loss      : 8.492052095999742e-07
# Valid loss      : 0.0022555263886147566
# Train precision : 1.0
# Valid precision : 0.9925373134328358
# Train accuracy  : 1.0
# Valid accuracy  : 0.9964093357271095
# Train f1_score  : 1.0
# Valid f1_score  : 0.9925373134328358
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 58
# Train loss      : 1.9680684205720556e-06
# Valid loss      : 0.0026509569302670013
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9946140035906643
# Train f1_score  : 1.0
# Valid f1_score  : 0.9886792452830189
# Train recall    : 1.0
# Valid recall    : 0.9776119402985075
# > > > Epoch     : 59
# Train loss      : 1.1587944783854943e-06
# Valid loss      : 0.0022607470439091506
# Train precision : 1.0
# Valid precision : 0.9925373134328358
# Train accuracy  : 1.0
# Valid accuracy  : 0.9964093357271095
# Train f1_score  : 1.0
# Valid f1_score  : 0.9925373134328358
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 60
# Train loss      : 1.4225478560019985e-06
# Valid loss      : 0.00236154654099416
# Train precision : 1.0
# Valid precision : 0.9925373134328358
# Train accuracy  : 1.0
# Valid accuracy  : 0.9964093357271095
# Train f1_score  : 1.0
# Valid f1_score  : 0.9925373134328358
# Train recall    : 1.0
# Valid recall    : 0.9925373134328358
# > > > Epoch     : 61
# Train loss      : 1.9372253128765778e-05
# Valid loss      : 0.002803120623544075
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9946140035906643
# Train f1_score  : 1.0
# Valid f1_score  : 0.9886792452830189
# Train recall    : 1.0
# Valid recall    : 0.9776119402985075
# > > > Epoch     : 62
# Train loss      : 3.603836069948319e-06
# Valid loss      : 0.002593858047198222
# Train precision : 1.0
# Valid precision : 0.9924812030075187
# Train accuracy  : 1.0
# Valid accuracy  : 0.9946140035906643
# Train f1_score  : 1.0
# Valid f1_score  : 0.9887640449438202
# Train recall    : 1.0
# Valid recall    : 0.9850746268656716
# > > > Epoch     : 63
# Train loss      : 5.813980616459454e-07
# Valid loss      : 0.0025479837892768277
# Train precision : 1.0
# Valid precision : 0.9924812030075187
# Train accuracy  : 1.0
# Valid accuracy  : 0.9946140035906643
# Train f1_score  : 1.0
# Valid f1_score  : 0.9887640449438202
# Train recall    : 1.0
# Valid recall    : 0.9850746268656716
# > > > Epoch     : 64
# Train loss      : 1.4734763221231584e-06
# Valid loss      : 0.002554318573463502
# Train precision : 1.0
# Valid precision : 0.9924812030075187
# Train accuracy  : 1.0
# Valid accuracy  : 0.9946140035906643
# Train f1_score  : 1.0
# Valid f1_score  : 0.9887640449438202
# Train recall    : 1.0
# Valid recall    : 0.9850746268656716
# > > > Epoch     : 65
# Train loss      : 1.9379046070333375e-06
# Valid loss      : 0.0027050902973874873
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9946140035906643
# Train f1_score  : 1.0
# Valid f1_score  : 0.9886792452830189
# Train recall    : 1.0
# Valid recall    : 0.9776119402985075
# > > > Epoch     : 66
# Train loss      : 1.7562327035408023e-06
# Valid loss      : 0.0028541812955784735
# Train precision : 1.0
# Valid precision : 1.0
# Train accuracy  : 1.0
# Valid accuracy  : 0.9946140035906643
# Train f1_score  : 1.0
# Valid f1_score  : 0.9886792452830189
# Train recall    : 1.0
# Valid recall    : 0.9776119402985075
# The validation f1 score is not increasing for continuous 10 time, so training stop
# CPU times: total: 4min 16s
# Wall time: 12min 40s

# %% [markdown]
# ### Test the model performance on testing dataset

# %%
# Load the best model and turn to evaluation mode
model.eval()
state_dict_loaded = torch.load(f"{MODEL_FILE_DIRC_CNN}/CNN_best.pt")
model.load_state_dict(state_dict_loaded["model"])

test_loss, test_metric = evaluate_classifier(model, test_data, device, num_test_data, LOSS_POS_WEIGHT=torch.tensor([3]))

print("Best model is at epoch:",state_dict_loaded["epoch"])
print("Metric on testing dataset:")
for key, value in test_metric.items():
    print(f"{key:<10}: {value:.4f}")
# Out:
# Best model is at epoch: 56
# Metric on testing dataset:
# precision : 1.0000
# accuracy  : 0.9820
# f1_score  : 0.9612
# recall    : 0.9254
