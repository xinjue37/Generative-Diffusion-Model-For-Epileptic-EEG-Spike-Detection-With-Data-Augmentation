# %% [markdown]
# ## Import all require library

# %%
import mne
import numpy as np
import pandas as pd
import os
from datetime import datetime, timedelta
import pytz
from utility import *
import json 
from ummc_db_util import Compumedics

pd.set_option('display.max_rows', 500)

# %% [markdown]
# ## Look at the structure of the annotation

# %%
# Structure of the edf file 
filename = f"{EEG_FILE_DIRC}/Export-#1495_2654_2023-11-30_14-36-51.eeg"
raw = Compumedics(filename).export_to_mne_raw() # Return a raw object
annotation_df = raw.annotations.to_data_frame()
annotation_df
# Out:
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\export-#1495_2654_2023-11-30_14-36-51.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\eegdata\eegdata.ini
# Opening all (1) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [825776]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 223 event(s), 102 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 825776)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 223 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 198 segments: 0 (3), 0.50 (7), 10 (3), 10 s/page (1), 10-20 ...>
# Creating RawArray with float64 data, n_channels=33, n_times=825776
#     Range : 0 ... 825775 =      0.000 ...  3225.684 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# Raw: <RawArray | 33 x 825776 (3225.7 s), ~207.9 MB, data loaded>
# Conversion complete
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 16 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
#                          onset  duration                 description
# 0   1970-01-01 00:00:00.456000       0.0           Calibration 10-20
# 1   1970-01-01 00:00:00.456000       0.0                         100
# 2   1970-01-01 00:00:00.456000       0.0                           0
# 3   1970-01-01 00:00:00.456000       0.0                        0.50
# 4   1970-01-01 00:00:00.456000       0.0                          10
# 5   1970-01-01 00:00:00.456000       0.0                         100
# 6   1970-01-01 00:00:00.456000       0.0                           0
# 7   1970-01-01 00:00:00.456000       0.0                        0.50
# 8   1970-01-01 00:00:00.456000       0.0                         100
# 9   1970-01-01 00:00:00.456000       0.0                         100
# 10  1970-01-01 00:00:00.456000       0.0                           0
# 11  1970-01-01 00:00:00.456000       0.0                        0.50
# 12  1970-01-01 00:00:00.456000       0.0                         100
# 13  1970-01-01 00:00:00.456000       0.0                   10 s/page
# 14  1970-01-01 00:00:01.645000       0.0                       10-20
# 15  1970-01-01 00:00:05.203125       0.0                 Probe Error
# 16  1970-01-01 00:03:42.068207       0.0         Com Average (T1-T2)
# 17  1970-01-01 00:03:44.631463       0.0                          50
# 18  1970-01-01 00:03:52.365237       0.0                          50
# 19  1970-01-01 00:03:53.487349       0.0                        0.50
# 20  1970-01-01 00:03:56.545655       0.0                         100
# 21  1970-01-01 00:03:57.733773       0.0                          50
# 22  1970-01-01 00:03:59.103410       0.0                        0.50
# 23  1970-01-01 00:04:15.082508       0.0                 Eyes Closed
# 24  1970-01-01 00:04:22.558410       0.0                 Eyes Closed
# 25  1970-01-01 00:04:32.871287       0.0                   Eyes Open
# 26  1970-01-01 00:04:36.925193       0.0                 Eyes Closed
# 27  1970-01-01 00:05:06.881188       0.0                      Drowsy
# 28  1970-01-01 00:05:35.522552       0.0                      Drowsy
# 29  1970-01-01 00:05:59.675468       0.0                      Drowsy
# 30  1970-01-01 00:06:01.628163       0.0                      Drowsy
# 31  1970-01-01 00:06:21.534653       0.0                      Drowsy
# 32  1970-01-01 00:06:52.205721       0.0                     AROUSAL
# 33  1970-01-01 00:07:13.993399       0.0                      Drowsy
# 34  1970-01-01 00:07:20.698570       0.0                     AROUSAL
# 35  1970-01-01 00:08:54.675468       0.0                     AROUSAL
# 36  1970-01-01 00:09:37.766777       0.0                      Drowsy
# 37  1970-01-01 00:10:53.713125       0.0                      Drowsy
# 141 1970-01-01 00:48:35.100745       0.0                          10
# 142 1970-01-01 00:48:45.080859       0.0                          11
# 143 1970-01-01 00:48:52.826948       0.0                          11
# 144 1970-01-01 00:49:02.632060       0.0                          12
# 145 1970-01-01 00:49:11.834179       0.0                          12
# 146 1970-01-01 00:49:20.512007       0.0                          13
# 147 1970-01-01 00:49:27.736864       0.0                          13
# 148 1970-01-01 00:49:35.902702       0.0                          14
# 149 1970-01-01 00:49:43.160559       0.0                          14
# 150 1970-01-01 00:49:52.395376       0.0                          15
# 151 1970-01-01 00:49:59.383238       0.0                          15
# 152 1970-01-01 00:50:07.476078       0.0                          17
# 153 1970-01-01 00:50:14.927792       0.0                          17
# 154 1970-01-01 00:50:25.707557       0.0                          17
# 155 1970-01-01 00:50:34.086374       0.0                          17
# 156 1970-01-01 00:50:42.611187       0.0                          19
# 157 1970-01-01 00:50:51.031003       0.0                          19
# 158 1970-01-01 00:51:01.833767       0.0                          21
# 159 1970-01-01 00:51:09.060313       0.0                          21
# 160 1970-01-01 00:51:16.716990       0.0                          23
# 161 1970-01-01 00:51:24.957719       0.0                          23
# 162 1970-01-01 00:51:34.113528       0.0                          25
# 163 1970-01-01 00:51:40.806120       0.0                          25
# 164 1970-01-01 00:51:49.371878       0.0                          27
# 165 1970-01-01 00:51:56.992552       0.0                          27
# 166 1970-01-01 00:52:13.910891       0.0                   Eyes Open
# 167 1970-01-01 00:52:22.898790       0.0                   Eyes Open
# 168 1970-01-01 00:52:34.812981       0.0         Com Average (T1-T2)
# 169 1970-01-01 00:52:39.059406       0.0                          50
# 170 1970-01-01 00:52:42.057206       0.0                          50
# 171 1970-01-01 00:52:44.983498       0.0                         100
# 172 1970-01-01 00:52:46.050605       0.0                          50
# 173 1970-01-01 00:52:47.172717       0.0                        0.50
# 174 1970-01-01 00:52:52.722772       0.0                 Eyes Closed
# 175 1970-01-01 00:53:00.649065       0.0                 Eyes Closed
# 176 1970-01-01 00:53:12.442244       0.0                   Eyes Open
# 177 1970-01-01 00:53:19.367437       0.0                 Eyes Closed
# 178 1970-01-01 00:53:28.542354       0.0                   Eyes Open
# 179 1970-01-01 00:53:31.474147       0.0                 Eyes Closed
# 180 1970-01-01 00:53:40.685794       0.0                   Eyes Open
# 181 1970-01-01 00:53:44.328933       0.0                 CALCULATING

# %% [markdown]
# ## Preprocessing the data from edf to csv

# %% [markdown]
# ### Find duration to skip and spike location

# %%
utc              = pytz.UTC
SECONDS_TO_TRASH = 10         # Choosing difference SECONDS_TO_TRASH will have the effect on value inside eeg due to the function (mne.resample) 
dict_spike       = {}
dict_duration    = {}

for filename in os.listdir(EEG_FILE_DIRC):
    if filename.endswith(".eeg"):
            edf_filename = f"{EEG_FILE_DIRC}/" + filename

            dict_spike[edf_filename] = []
            print("For the file:",edf_filename)
            
            # Load the edf file and get the annotation of data
            raw = Compumedics(edf_filename).export_to_mne_raw()  # Return a raw object

            annotation_df     = raw.annotations.to_data_frame()                   # Annotation of the data in dataframe format
            
            # ---------- FIND DURATION TO SKIP ---------- 
            clean_data_before = 0                                                 # Initialize start time as 0

            # Find the calibration duration (if there is any)
            for i, description in enumerate(annotation_df["description"]):  # For each of the descriptions
                if description.lower().__contains__("calibration"):         # If it contain the word 'calibration'
                    print("Description contain 'calibration'",annotation_df.iloc[i,:].to_numpy(), "\n")               

                    # Obtain the start time of the annotation and its duration
                    annotated_start   = annotation_df.iloc[i,0].timestamp()  # Convert to total seconds
                    duration          = annotation_df.iloc[i,1]
                    temp              = annotated_start+duration
                    
                    if temp < 300 and temp > clean_data_before: # If calibration less than 5m=300s, and it is > than initial time
                        clean_data_before = temp
            
            duration_to_skip = clean_data_before        # Duration to throw from the measurement date
            duration_to_skip = np.ceil(duration_to_skip) + SECONDS_TO_TRASH
            print("Duration to skip from the measurement date: ", duration_to_skip)


            # ---------- FIND SPIKE LOCATION (if there is any) ----------    
            for i, description in enumerate(annotation_df["description"]):
                if description.lower().__contains__("spike"):                 # If it contain the word 'spike'
                    print("Description contain 'spike'", annotation_df.iloc[i,:].to_numpy())

                    # Obtain the start time of the spike occur
                    annotated_start   = annotation_df.iloc[i,0].timestamp()
                    dict_spike[edf_filename].append(annotated_start - duration_to_skip)
            dict_duration[edf_filename] = duration_to_skip
# Out:
# For the file: EEG_Dataset/Export-#1495_2654_2023-11-30_14-36-51.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\export-#1495_2654_2023-11-30_14-36-51.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\eegdata\eegdata.ini
# Opening all (1) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [825776]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 223 event(s), 102 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 825776)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 223 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 198 segments: 0 (3), 0.50 (7), 10 (3), 10 s/page (1), 10-20 ...>
# Creating RawArray with float64 data, n_channels=33, n_times=825776
#     Range : 0 ... 825775 =      0.000 ...  3225.684 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 16 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 825776 (3225.7 s), ~207.9 MB, data loaded>
# Conversion complete
# Description contain 'calibration' [Timestamp('1970-01-01 00:00:00.456000') 0.0 'Calibration 10-20']
#
# Duration to skip from the measurement date:  11.0
# Description contain 'spike' [Timestamp('1970-01-01 00:15:40.916725') 0.0 '? Small Spike and Slow']
# For the file: EEG_Dataset/Export-#1495_2656_2023-11-29_10-12-39.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2656_2023-11-29_10-12-39.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2656_2023-11-29_10-12-39.eeg\export-#1495_2656_2023-11-29_10-12-39.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2656_2023-11-29_10-12-39.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2656_2023-11-29_10-12-39.eeg\eegdata\eegdata.ini
# Opening all (1) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2656_2023-11-29_10-12-39.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 2 segment(s), n_samples: [8432, 814896]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2656_2023-11-29_10-12-39.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2656_2023-11-29_10-12-39.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2656_2023-11-29_10-12-39.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 211 event(s), 88 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 823328)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 211 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 192 segments: 0 (3), 0.50 (3), 1 (1), 10 (3), 10 s/page ...>
# Creating RawArray with float64 data, n_channels=33, n_times=823328
#     Range : 0 ... 823327 =      0.000 ...  3216.121 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 130 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 823328 (3216.1 s), ~207.3 MB, data loaded>
# Conversion complete
# Description contain 'calibration' [Timestamp('1970-01-01 00:00:00.400000') 0.0 'Calibration 10-20']
#
# Duration to skip from the measurement date:  11.0
# For the file: EEG_Dataset/Export-#1495_2657_2023-11-09_14-08-53.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2657_2023-11-09_14-08-53.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2657_2023-11-09_14-08-53.eeg\export-#1495_2657_2023-11-09_14-08-53.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2657_2023-11-09_14-08-53.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2657_2023-11-09_14-08-53.eeg\eegdata\eegdata.ini
# Opening all (1) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2657_2023-11-09_14-08-53.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [786480]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2657_2023-11-09_14-08-53.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2657_2023-11-09_14-08-53.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2657_2023-11-09_14-08-53.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 223 event(s), 116 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 786480)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 223 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 194 segments: 0 (3), 0.50 (5), 1 (2), 10 (3), 10 s/page ...>
# Creating RawArray with float64 data, n_channels=33, n_times=786480
#     Range : 0 ... 786479 =      0.000 ...  3072.184 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 34 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 786480 (3072.2 s), ~198.0 MB, data loaded>
# Conversion complete
# Description contain 'calibration' [Timestamp('1970-01-01 00:00:00.437000') 0.0 'Calibration 10-20']
#
# Duration to skip from the measurement date:  11.0
# For the file: EEG_Dataset/Export-#1495_2658_2022-10-21_14-23-50.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2658_2022-10-21_14-23-50.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2658_2022-10-21_14-23-50.eeg\export-#1495_2658_2022-10-21_14-23-50.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2658_2022-10-21_14-23-50.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2658_2022-10-21_14-23-50.eeg\eegdata\eegdata.ini
# Opening all (1) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2658_2022-10-21_14-23-50.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 2 segment(s), n_samples: [3952, 873776]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2658_2022-10-21_14-23-50.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2658_2022-10-21_14-23-50.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2658_2022-10-21_14-23-50.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 87 event(s), 60 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 877728)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 87 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 70 segments: 0 (3), 0.50 (3), 10 (3), 10 s/page (1), 10-20 ...>
# Creating RawArray with float64 data, n_channels=33, n_times=877728
#     Range : 0 ... 877727 =      0.000 ...  3428.621 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 44 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 877728 (3428.6 s), ~221.0 MB, data loaded>
# Conversion complete
# Description contain 'calibration' [Timestamp('1970-01-01 00:00:00.411000') 0.0 'Calibration 10-20']
#
# Duration to skip from the measurement date:  11.0
# For the file: EEG_Dataset/Export-#1495_2659_2023-11-28_14-02-43.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2659_2023-11-28_14-02-43.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2659_2023-11-28_14-02-43.eeg\export-#1495_2659_2023-11-28_14-02-43.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2659_2023-11-28_14-02-43.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2659_2023-11-28_14-02-43.eeg\eegdata\eegdata.ini
# Opening all (1) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2659_2023-11-28_14-02-43.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [764784]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2659_2023-11-28_14-02-43.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2659_2023-11-28_14-02-43.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2659_2023-11-28_14-02-43.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 179 event(s), 84 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 764784)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 179 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 154 segments: 0 (4), 0.50 (8), 1 (2), 10 (3), 10 s/page ...>
# Creating RawArray with float64 data, n_channels=33, n_times=764784
#     Range : 0 ... 764783 =      0.000 ...  2987.434 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 91 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 764784 (2987.4 s), ~192.6 MB, data loaded>
# Conversion complete
# Description contain 'calibration' [Timestamp('1970-01-01 00:00:00.488000') 0.0 'Calibration 10-20']
#
# Duration to skip from the measurement date:  11.0
# For the file: EEG_Dataset/Export-#1495_2660_2023-11-15_10-07-03.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2660_2023-11-15_10-07-03.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2660_2023-11-15_10-07-03.eeg\export-#1495_2660_2023-11-15_10-07-03.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2660_2023-11-15_10-07-03.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2660_2023-11-15_10-07-03.eeg\eegdata\eegdata.ini
# Opening all (2) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2660_2023-11-15_10-07-03.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [1003727]
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2660_2023-11-15_10-07-03.eeg\eegdata\eegdata-1.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [61377]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2660_2023-11-15_10-07-03.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2660_2023-11-15_10-07-03.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2660_2023-11-15_10-07-03.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 143 event(s), 98 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 1065104)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 143 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 117 segments: 0 (3), 0.50 (6), 00:31 (1), 01:00 (1), 01:30 ...>
# Creating RawArray with float64 data, n_channels=33, n_times=1065104
#     Range : 0 ... 1065103 =      0.000 ...  4160.559 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 87 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 1065104 (4160.6 s), ~268.2 MB, data loaded>
# Conversion complete
# Description contain 'calibration' [Timestamp('1970-01-01 00:00:00.477000') 0.0 'Calibration 10-20']
#
# Duration to skip from the measurement date:  11.0
# For the file: EEG_Dataset/Export-#1495_2663_2023-11-29_13-45-07.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2663_2023-11-29_13-45-07.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2663_2023-11-29_13-45-07.eeg\export-#1495_2663_2023-11-29_13-45-07.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2663_2023-11-29_13-45-07.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2663_2023-11-29_13-45-07.eeg\eegdata\eegdata.ini
# Opening all (1) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2663_2023-11-29_13-45-07.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [759216]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2663_2023-11-29_13-45-07.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2663_2023-11-29_13-45-07.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2663_2023-11-29_13-45-07.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 235 event(s), 98 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 759216)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 235 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 207 segments: 0 (3), 0.50 (7), 1 (2), 10 (3), 10 s/page ...>
# Creating RawArray with float64 data, n_channels=33, n_times=759216
#     Range : 0 ... 759215 =      0.000 ...  2965.684 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 138 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 759216 (2965.7 s), ~191.2 MB, data loaded>
# Conversion complete
# Description contain 'calibration' [Timestamp('1970-01-01 00:00:00.400000') 0.0 'Calibration 10-20']
#
# Duration to skip from the measurement date:  11.0
# For the file: EEG_Dataset/Export-#1495_2667_2022-04-12_14-31-14.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2667_2022-04-12_14-31-14.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2667_2022-04-12_14-31-14.eeg\export-#1495_2667_2022-04-12_14-31-14.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2667_2022-04-12_14-31-14.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2667_2022-04-12_14-31-14.eeg\eegdata\eegdata.ini
# Opening all (1) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2667_2022-04-12_14-31-14.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 2 segment(s), n_samples: [12720, 974864]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2667_2022-04-12_14-31-14.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2667_2022-04-12_14-31-14.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2667_2022-04-12_14-31-14.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 206 event(s), 120 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 987584)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 206 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 147 segments: 0 (4), 0.50 (3), 00:31 (2), 01:00 (2), 01:30 ...>
# Creating RawArray with float64 data, n_channels=33, n_times=987584
#     Range : 0 ... 987583 =      0.000 ...  3857.746 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 112 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 987584 (3857.7 s), ~248.7 MB, data loaded>
# Conversion complete
# Description contain 'calibration' [Timestamp('1970-01-01 00:00:00.475000') 0.0 'Calibration 10-20']
#
# Duration to skip from the measurement date:  11.0
# Description contain 'spike' [Timestamp('1970-01-01 01:01:12.779273') 0.0 '14hz positive spike ']
# For the file: EEG_Dataset/Export-#1495_2669_2023-11-27_11-39-39.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2669_2023-11-27_11-39-39.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2669_2023-11-27_11-39-39.eeg\export-#1495_2669_2023-11-27_11-39-39.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2669_2023-11-27_11-39-39.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2669_2023-11-27_11-39-39.eeg\eegdata\eegdata.ini
# Opening all (2) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2669_2023-11-27_11-39-39.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 2 segment(s), n_samples: [803248, 674058]
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2669_2023-11-27_11-39-39.eeg\eegdata\eegdata-1.rda
# Reading .rda segments...
# Read 2 segment(s), n_samples: [253702, 140192]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2669_2023-11-27_11-39-39.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2669_2023-11-27_11-39-39.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2669_2023-11-27_11-39-39.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 257 event(s), 110 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 1871200)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 257 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 183 segments: 0 (8), 0.50 (10), 10 (6), 10 s/page (2), ...>
# Creating RawArray with float64 data, n_channels=33, n_times=1871200
#     Range : 0 ... 1871199 =      0.000 ...  7309.371 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 34 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 1871200 (7309.4 s), ~471.1 MB, data loaded>
# Conversion complete
# Description contain 'calibration' [Timestamp('1970-01-01 00:00:00.460000') 0.0 'Calibration 10-20']
#
# Description contain 'calibration' [Timestamp('1970-01-01 01:00:12.326000') 0.0 'Calibration 10-20']
#
# Duration to skip from the measurement date:  11.0
# Description contain 'spike' [Timestamp('1970-01-01 01:36:50.749460') 0.0
#  'runs of slow frontal? spike??']
# For the file: EEG_Dataset/Export-#1496_2670_2023-11-29_15-45-36.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1496_2670_2023-11-29_15-45-36.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1496_2670_2023-11-29_15-45-36.eeg\export-#1496_2670_2023-11-29_15-45-36.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1496_2670_2023-11-29_15-45-36.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1496_2670_2023-11-29_15-45-36.eeg\eegdata\eegdata.ini
# Opening all (1) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1496_2670_2023-11-29_15-45-36.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 2 segment(s), n_samples: [5456, 558752]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1496_2670_2023-11-29_15-45-36.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1496_2670_2023-11-29_15-45-36.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1496_2670_2023-11-29_15-45-36.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 145 event(s), 78 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 564208)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# ...
# Description contain 'spike' [Timestamp('1970-01-01 04:35:26.584923') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:35:33.351499') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:36:08.138056') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:36:12.279746') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:36:42.570391') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:37:05.767484') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:37:20.372389') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:40:34.405086') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:44:08.274296') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:44:41.734787') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:44:54.804723') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:45:05.567666') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:46:04.477748') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:47:04.114441') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:47:16.784741') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:47:41.416894') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:50:15.531335') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:55:16.267030') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:56:52.116258') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 04:58:05.513170') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 05:03:44.386921') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 05:03:56.257947') 0.0 'SPIKE / POLYSPIKES']
# Description contain 'spike' [Timestamp('1970-01-01 05:04:54.704814') 0.0 'SPIKE / POLYSPIKES']
# For the file: EEG_Dataset/Export-#1497_2682_2023-11-22_00-32-49.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\export-#1497_2682_2023-11-22_00-32-49.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\eegdata\eegdata.ini
# Opening all (5) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [1595413]
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\eegdata\eegdata-1.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [1600000]
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\eegdata\eegdata-2.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [1600000]
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\eegdata\eegdata-3.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [1600000]
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\eegdata\eegdata-4.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [84683]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 60 event(s), 26 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 6480096)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 60 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 59 segments: 0 (3), 0.50 (3), 10 (3), 10 s/page (1), 10-20 ...>
# Creating RawArray with float64 data, n_channels=33, n_times=6480096
#     Range : 0 ... 6480095 =      0.000 ... 25312.871 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# Raw: <RawArray | 33 x 6480096 (25312.9 s), ~1.59 GB, data loaded>
# Conversion complete
# Description contain 'calibration' [Timestamp('1970-01-01 00:00:02.576000') 0.0 'Calibration 10-20']
#
# Duration to skip from the measurement date:  13.0
# Description contain 'spike' [Timestamp('1970-01-01 00:23:13.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 00:23:33.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 00:24:33.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 00:25:13.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 00:25:43.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 00:26:23.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 00:29:03.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 00:29:43.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 00:31:03.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 00:31:53.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 00:32:23.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 00:34:23.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 00:38:33.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 00:43:33.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 00:43:53.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 00:44:33.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 00:44:53.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 00:46:53.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 00:53:53.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 01:31:13.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 01:36:33.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 01:38:03.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 01:38:23.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 01:39:33.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 01:41:03.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 01:41:23.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 01:43:23.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 01:44:03.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 01:46:13.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 01:47:33.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 01:48:03.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 01:50:03.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 01:50:23.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 01:50:53.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 01:52:03.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 02:42:53.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 02:43:43.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 02:44:53.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 02:45:03.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 02:46:03.358272') 0.0 'Spike']
# Description contain 'spike' [Timestamp('1970-01-01 02:46:33.358272') 0.0 'Spike']
# For the file: EEG_Dataset/Export-#1497_2683_2022-09-09_11-56-39.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2683_2022-09-09_11-56-39.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2683_2022-09-09_11-56-39.eeg\export-#1497_2683_2022-09-09_11-56-39.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2683_2022-09-09_11-56-39.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2683_2022-09-09_11-56-39.eeg\eegdata\eegdata.ini
# Opening all (1) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2683_2022-09-09_11-56-39.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 2 segment(s), n_samples: [3056, 491792]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2683_2022-09-09_11-56-39.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2683_2022-09-09_11-56-39.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2683_2022-09-09_11-56-39.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 171 event(s), 116 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 494848)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 171 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 143 segments: 0 (3), 0.50 (8), 1 (3), 10 (6), 10 s/page ...>
# Creating RawArray with float64 data, n_channels=33, n_times=494848
#     Range : 0 ... 494847 =      0.000 ...  1932.996 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# Raw: <RawArray | 33 x 494848 (1933.0 s), ~124.6 MB, data loaded>
# Conversion complete
# Description contain 'calibration' [Timestamp('1970-01-01 00:00:00.870000') 0.0 'Calibration 10-20']
#
# Duration to skip from the measurement date:  11.0
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 126 annotation(s) that were outside data range.
#   raw.set_annotations(ann)

# %% [markdown]
# ### Print out duration to skip and spike location for each file

# %%
count              = 0
num_spike          = 0
file_contain_spike = []
dict_spike_csv     = {}

for i, (filename, spike) in enumerate(dict_spike.items(), 1):
    if spike != []: 
        count+=1
        num_spike += len(spike)
        file_contain_spike.append(filename)
        
        print(filename, f"\teeg{i}\t", len(spike), spike, "\n")
        dict_spike_csv[f"eeg{i}"] = spike
    else:
        dict_spike_csv[f"eeg{i}"] = []
    
print(f"There is {count} file that contain spike, among them, there is total {num_spike} spikes")
# Out:
# EEG_Dataset/Export-#1495_2654_2023-11-30_14-36-51.eeg 	eeg1	 1 [929.916725]
#
# EEG_Dataset/Export-#1495_2667_2022-04-12_14-31-14.eeg 	eeg8	 1 [3661.779273]
#
# EEG_Dataset/Export-#1495_2669_2023-11-27_11-39-39.eeg 	eeg9	 1 [5799.74946]
#
# EEG_Dataset/Export-#1496_2672_2023-11-22_07-44-26.eeg 	eeg12	 9 [3262.867508, 4587.214511, 4795.466877, 4800.463722, 4805.416404, 4821.876972, 4872.003155, 4882.987382, 14466.04796]
#
# EEG_Dataset/Export-#1496_2677_2023-11-22_08-09-49.eeg 	eeg15	 56 [391.702797, 421.924242, 617.938228, 1170.148649, 1281.918919, 1570.959459, 1603.77027, 1609.324324, 2922.357776, 3209.460083, 3256.461857, 3481.263749, 4652.570668, 4813.759314, 4861.387936, 4894.380248, 5185.574808, 5315.285038, 5353.345358, 5467.792431, 5870.234772, 5883.274394, 5904.965701, 7414.374335, 7630.690124, 7638.821407, 7661.482555, 7713.114725, 7914.096393, 8042.115316, 8526.172494, 8560.321678, 8572.099068, 8594.051282, 8597.949883, 8614.762238, 8638.340326, 8650.310023, 8658.223776, 8722.180653, 8731.172494, 8753.229604, 8770.082751, 8825.006993, 8833.876457, 8859.278555, 8909.29021, 8948.940559, 9092.09324, 9193.853147, 9248.689977, 9333.328671, 9357.629371, 9375.041958, 9405.222611, 9523.777389]
#
# EEG_Dataset/Export-#1497_2682_2023-11-22_00-32-49.eeg 	eeg19	 41 [1380.358272, 1400.358272, 1460.358272, 1500.358272, 1530.358272, 1570.358272, 1730.358272, 1770.358272, 1850.358272, 1900.358272, 1930.358272, 2050.358272, 2300.358272, 2600.358272, 2620.358272, 2660.358272, 2680.358272, 2800.358272, 3220.358272, 5460.358272, 5780.358272, 5870.358272, 5890.358272, 5960.358272, 6050.358272, 6070.358272, 6190.358272, 6230.358272, 6360.358272, 6440.358272, 6470.358272, 6590.358272, 6610.358272, 6640.358272, 6710.358272, 9760.358272, 9810.358272, 9880.358272, 9890.358272, 9950.358272, 9980.358272]
#
# There is 8 file that contain spike, among them, there is total 301 spikes

# %%
for filename, duration in dict_duration.items():
    print(f"For the file: {filename:<35}, Duration to skip from beginning: {duration} s")
# Out:
# For the file: EEG_Dataset/Export-#1495_2654_2023-11-30_14-36-51.eeg, Duration to skip from beginning: 11.0 s
# For the file: EEG_Dataset/Export-#1495_2656_2023-11-29_10-12-39.eeg, Duration to skip from beginning: 11.0 s
# For the file: EEG_Dataset/Export-#1495_2657_2023-11-09_14-08-53.eeg, Duration to skip from beginning: 11.0 s
# For the file: EEG_Dataset/Export-#1495_2658_2022-10-21_14-23-50.eeg, Duration to skip from beginning: 11.0 s
# For the file: EEG_Dataset/Export-#1495_2659_2023-11-28_14-02-43.eeg, Duration to skip from beginning: 11.0 s
# For the file: EEG_Dataset/Export-#1495_2660_2023-11-15_10-07-03.eeg, Duration to skip from beginning: 11.0 s
# For the file: EEG_Dataset/Export-#1495_2663_2023-11-29_13-45-07.eeg, Duration to skip from beginning: 11.0 s
# For the file: EEG_Dataset/Export-#1495_2667_2022-04-12_14-31-14.eeg, Duration to skip from beginning: 11.0 s
# For the file: EEG_Dataset/Export-#1495_2669_2023-11-27_11-39-39.eeg, Duration to skip from beginning: 11.0 s
# For the file: EEG_Dataset/Export-#1496_2670_2023-11-29_15-45-36.eeg, Duration to skip from beginning: 11.0 s
# For the file: EEG_Dataset/Export-#1496_2671_2023-11-06_11-34-05.eeg, Duration to skip from beginning: 11.0 s
# For the file: EEG_Dataset/Export-#1496_2672_2023-11-22_07-44-26.eeg, Duration to skip from beginning: 13.0 s
# For the file: EEG_Dataset/Export-#1496_2674_2022-08-16_09-02-10.eeg, Duration to skip from beginning: 12.0 s
# For the file: EEG_Dataset/Export-#1496_2675_2023-11-10_10-04-47.eeg, Duration to skip from beginning: 11.0 s
# For the file: EEG_Dataset/Export-#1496_2677_2023-11-22_08-09-49.eeg, Duration to skip from beginning: 13.0 s
# For the file: EEG_Dataset/Export-#1497_2679_2023-11-30_14-36-45.eeg, Duration to skip from beginning: 14.0 s
# For the file: EEG_Dataset/Export-#1497_2680_2023-11-21_20-55-45.eeg, Duration to skip from beginning: 13.0 s
# For the file: EEG_Dataset/Export-#1497_2681_2023-09-11_09-59-42.eeg, Duration to skip from beginning: 14.0 s
# For the file: EEG_Dataset/Export-#1497_2682_2023-11-22_00-32-49.eeg, Duration to skip from beginning: 13.0 s
# For the file: EEG_Dataset/Export-#1497_2683_2022-09-09_11-56-39.eeg, Duration to skip from beginning: 11.0 s

# %% [markdown]
# ### Save the annotation of spike into json file

# %%
with open(f"{CSV_FILE_DIRC}/annotation.json", "w") as f: 
    json.dump(dict_spike_csv, f)

# %%
with open(f"{CSV_FILE_DIRC}/annotation.json", "r") as f:
    dict1 = json.load(f)
    print(dict1)
# Out:
 12409.242507, 12447.843778, 12548.770209, 12565.673025, 12936.372389, 12965.673025, 13007.207993, 14752.821072, 14772.276113, 14781.213442, 14789.242507, 14820.595822, 14863.929155, 15490.859219, 15507.480472, 16475.82743, 16512.584923, 16519.351499, 16554.138056, 16558.279746, 16588.570391, 16611.767484, 16626.372389, 16820.405086, 17034.274296, 17067.734787, 17080.804723, 17091.567666, 17150.477748, 17210.114441, 17222.784741, 17247.416894, 17401.531335, 17702.26703, 17798.116258, 17871.51317, 18210.386921, 18222.257947, 18280.704814], 'eeg19': [1380.358272, 1400.358272, 1460.358272, 1500.358272, 1530.358272, 1570.358272, 1730.358272, 1770.358272, 1850.358272, 1900.358272, 1930.358272, 2050.358272, 2300.358272, 2600.358272, 2620.358272, 2660.358272, 2680.358272, 2800.358272, 3220.358272, 5460.358272, 5780.358272, 5870.358272, 5890.358272, 5960.358272, 6050.358272, 6070.358272, 6190.358272, 6230.358272, 6360.358272, 6440.358272, 6470.358272, 6590 ...

# %% [markdown]
# ### Preprocess the EEG data
# * remain only 19 channels
# * apply average montage
# * apply band pass filter
# * Resample the data from 256 Hz to 128 Hz

# %%
# %%time
num = 1

for filename in os.listdir(EEG_FILE_DIRC):
    if filename.endswith(".eeg"):
            # Load the edf file and get the annotation of data
            if not os.path.exists(f"{CSV_FILE_DIRC}/eeg{num}.csv"): # If end with .edf, and the file haven't been process
                eeg_filename = f"{EEG_FILE_DIRC}/" + filename
                process_edf(eeg_filename, num, 
                            SKIP_FIRST=dict_duration[edf_filename], 
                            SKIP_LAST=SECONDS_TO_TRASH)    
            num += 1
# Out:
# For the file:  EEG_Dataset/Export-#1495_2654_2023-11-30_14-36-51.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\export-#1495_2654_2023-11-30_14-36-51.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\eegdata\eegdata.ini
# Opening all (1) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [825776]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2654_2023-11-30_14-36-51.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 223 event(s), 102 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 825776)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 223 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 198 segments: 0 (3), 0.50 (7), 10 (3), 10 s/page (1), 10-20 ...>
# Creating RawArray with float64 data, n_channels=33, n_times=825776
#     Range : 0 ... 825775 =      0.000 ...  3225.684 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 16 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 825776 (3225.7 s), ~207.9 MB, data loaded>
# Conversion complete
# Before drop some row, shape = (825776, 34)
# After  drop some row, shape = (820400, 34)
# Setting up band-pass filter from 0.5 - 70 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 70.00 Hz
# - Upper transition bandwidth: 17.50 Hz (-6 dB cutoff frequency: 78.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=820400
#     Range : 0 ... 820399 =      0.000 ...  3204.684 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# EEG_Dataset/Export-#1495_2654_2023-11-30_14-36-51.eeg does not contain NULL value, the process will continue
# The dataframe of EEG_Dataset/Export-#1495_2654_2023-11-30_14-36-51.eeg have been saved to EEG_csv/eeg1.csv
#
# For the file:  EEG_Dataset/Export-#1495_2656_2023-11-29_10-12-39.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2656_2023-11-29_10-12-39.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2656_2023-11-29_10-12-39.eeg\export-#1495_2656_2023-11-29_10-12-39.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2656_2023-11-29_10-12-39.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2656_2023-11-29_10-12-39.eeg\eegdata\eegdata.ini
# Opening all (1) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2656_2023-11-29_10-12-39.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 2 segment(s), n_samples: [8432, 814896]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2656_2023-11-29_10-12-39.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2656_2023-11-29_10-12-39.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2656_2023-11-29_10-12-39.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 211 event(s), 88 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 823328)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 211 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 192 segments: 0 (3), 0.50 (3), 1 (1), 10 (3), 10 s/page ...>
# Creating RawArray with float64 data, n_channels=33, n_times=823328
#     Range : 0 ... 823327 =      0.000 ...  3216.121 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 130 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 823328 (3216.1 s), ~207.3 MB, data loaded>
# Conversion complete
# Before drop some row, shape = (823328, 34)
# After  drop some row, shape = (817952, 34)
# Setting up band-pass filter from 0.5 - 70 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 70.00 Hz
# - Upper transition bandwidth: 17.50 Hz (-6 dB cutoff frequency: 78.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=817952
#     Range : 0 ... 817951 =      0.000 ...  3195.121 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# EEG_Dataset/Export-#1495_2656_2023-11-29_10-12-39.eeg does not contain NULL value, the process will continue
# The dataframe of EEG_Dataset/Export-#1495_2656_2023-11-29_10-12-39.eeg have been saved to EEG_csv/eeg2.csv
#
# For the file:  EEG_Dataset/Export-#1495_2657_2023-11-09_14-08-53.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2657_2023-11-09_14-08-53.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2657_2023-11-09_14-08-53.eeg\export-#1495_2657_2023-11-09_14-08-53.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2657_2023-11-09_14-08-53.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2657_2023-11-09_14-08-53.eeg\eegdata\eegdata.ini
# Opening all (1) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2657_2023-11-09_14-08-53.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [786480]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2657_2023-11-09_14-08-53.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2657_2023-11-09_14-08-53.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2657_2023-11-09_14-08-53.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 223 event(s), 116 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 786480)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 223 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 194 segments: 0 (3), 0.50 (5), 1 (2), 10 (3), 10 s/page ...>
# Creating RawArray with float64 data, n_channels=33, n_times=786480
#     Range : 0 ... 786479 =      0.000 ...  3072.184 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 34 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 786480 (3072.2 s), ~198.0 MB, data loaded>
# Conversion complete
# Before drop some row, shape = (786480, 34)
# After  drop some row, shape = (781104, 34)
# Setting up band-pass filter from 0.5 - 70 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 70.00 Hz
# - Upper transition bandwidth: 17.50 Hz (-6 dB cutoff frequency: 78.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=781104
#     Range : 0 ... 781103 =      0.000 ...  3051.184 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# EEG_Dataset/Export-#1495_2657_2023-11-09_14-08-53.eeg does not contain NULL value, the process will continue
# The dataframe of EEG_Dataset/Export-#1495_2657_2023-11-09_14-08-53.eeg have been saved to EEG_csv/eeg3.csv
#
# For the file:  EEG_Dataset/Export-#1495_2658_2022-10-21_14-23-50.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2658_2022-10-21_14-23-50.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2658_2022-10-21_14-23-50.eeg\export-#1495_2658_2022-10-21_14-23-50.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2658_2022-10-21_14-23-50.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2658_2022-10-21_14-23-50.eeg\eegdata\eegdata.ini
# Opening all (1) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2658_2022-10-21_14-23-50.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 2 segment(s), n_samples: [3952, 873776]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2658_2022-10-21_14-23-50.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2658_2022-10-21_14-23-50.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2658_2022-10-21_14-23-50.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 87 event(s), 60 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 877728)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 87 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 70 segments: 0 (3), 0.50 (3), 10 (3), 10 s/page (1), 10-20 ...>
# Creating RawArray with float64 data, n_channels=33, n_times=877728
#     Range : 0 ... 877727 =      0.000 ...  3428.621 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 44 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 877728 (3428.6 s), ~221.0 MB, data loaded>
# Conversion complete
# Before drop some row, shape = (877728, 34)
# After  drop some row, shape = (872352, 34)
# Setting up band-pass filter from 0.5 - 70 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 70.00 Hz
# - Upper transition bandwidth: 17.50 Hz (-6 dB cutoff frequency: 78.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=872352
#     Range : 0 ... 872351 =      0.000 ...  3407.621 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# EEG_Dataset/Export-#1495_2658_2022-10-21_14-23-50.eeg does not contain NULL value, the process will continue
# The dataframe of EEG_Dataset/Export-#1495_2658_2022-10-21_14-23-50.eeg have been saved to EEG_csv/eeg4.csv
#
# For the file:  EEG_Dataset/Export-#1495_2659_2023-11-28_14-02-43.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2659_2023-11-28_14-02-43.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2659_2023-11-28_14-02-43.eeg\export-#1495_2659_2023-11-28_14-02-43.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2659_2023-11-28_14-02-43.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2659_2023-11-28_14-02-43.eeg\eegdata\eegdata.ini
# Opening all (1) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2659_2023-11-28_14-02-43.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [764784]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2659_2023-11-28_14-02-43.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2659_2023-11-28_14-02-43.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2659_2023-11-28_14-02-43.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 179 event(s), 84 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 764784)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 179 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 154 segments: 0 (4), 0.50 (8), 1 (2), 10 (3), 10 s/page ...>
# Creating RawArray with float64 data, n_channels=33, n_times=764784
#     Range : 0 ... 764783 =      0.000 ...  2987.434 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 91 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 764784 (2987.4 s), ~192.6 MB, data loaded>
# Conversion complete
# Before drop some row, shape = (764784, 34)
# After  drop some row, shape = (759408, 34)
# Setting up band-pass filter from 0.5 - 70 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 70.00 Hz
# - Upper transition bandwidth: 17.50 Hz (-6 dB cutoff frequency: 78.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=759408
#     Range : 0 ... 759407 =      0.000 ...  2966.434 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# EEG_Dataset/Export-#1495_2659_2023-11-28_14-02-43.eeg does not contain NULL value, the process will continue
# The dataframe of EEG_Dataset/Export-#1495_2659_2023-11-28_14-02-43.eeg have been saved to EEG_csv/eeg5.csv
#
# For the file:  EEG_Dataset/Export-#1495_2660_2023-11-15_10-07-03.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2660_2023-11-15_10-07-03.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2660_2023-11-15_10-07-03.eeg\export-#1495_2660_2023-11-15_10-07-03.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2660_2023-11-15_10-07-03.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2660_2023-11-15_10-07-03.eeg\eegdata\eegdata.ini
# Opening all (2) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2660_2023-11-15_10-07-03.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [1003727]
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2660_2023-11-15_10-07-03.eeg\eegdata\eegdata-1.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [61377]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2660_2023-11-15_10-07-03.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2660_2023-11-15_10-07-03.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2660_2023-11-15_10-07-03.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 143 event(s), 98 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 1065104)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 143 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 117 segments: 0 (3), 0.50 (6), 00:31 (1), 01:00 (1), 01:30 ...>
# Creating RawArray with float64 data, n_channels=33, n_times=1065104
#     Range : 0 ... 1065103 =      0.000 ...  4160.559 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 87 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 1065104 (4160.6 s), ~268.2 MB, data loaded>
# Conversion complete
# Before drop some row, shape = (1065104, 34)
# After  drop some row, shape = (1059728, 34)
# Setting up band-pass filter from 0.5 - 70 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 70.00 Hz
# - Upper transition bandwidth: 17.50 Hz (-6 dB cutoff frequency: 78.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=1059728
#     Range : 0 ... 1059727 =      0.000 ...  4139.559 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.4s
# EEG_Dataset/Export-#1495_2660_2023-11-15_10-07-03.eeg does not contain NULL value, the process will continue
# The dataframe of EEG_Dataset/Export-#1495_2660_2023-11-15_10-07-03.eeg have been saved to EEG_csv/eeg6.csv
#
# For the file:  EEG_Dataset/Export-#1495_2663_2023-11-29_13-45-07.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2663_2023-11-29_13-45-07.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2663_2023-11-29_13-45-07.eeg\export-#1495_2663_2023-11-29_13-45-07.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2663_2023-11-29_13-45-07.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2663_2023-11-29_13-45-07.eeg\eegdata\eegdata.ini
# Opening all (1) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2663_2023-11-29_13-45-07.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [759216]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2663_2023-11-29_13-45-07.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2663_2023-11-29_13-45-07.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2663_2023-11-29_13-45-07.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 235 event(s), 98 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 759216)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 235 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 207 segments: 0 (3), 0.50 (7), 1 (2), 10 (3), 10 s/page ...>
# Creating RawArray with float64 data, n_channels=33, n_times=759216
#     Range : 0 ... 759215 =      0.000 ...  2965.684 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 138 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 759216 (2965.7 s), ~191.2 MB, data loaded>
# Conversion complete
# Before drop some row, shape = (759216, 34)
# After  drop some row, shape = (753840, 34)
# Setting up band-pass filter from 0.5 - 70 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 70.00 Hz
# - Upper transition bandwidth: 17.50 Hz (-6 dB cutoff frequency: 78.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=753840
#     Range : 0 ... 753839 =      0.000 ...  2944.684 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# EEG_Dataset/Export-#1495_2663_2023-11-29_13-45-07.eeg does not contain NULL value, the process will continue
# The dataframe of EEG_Dataset/Export-#1495_2663_2023-11-29_13-45-07.eeg have been saved to EEG_csv/eeg7.csv
#
# For the file:  EEG_Dataset/Export-#1495_2667_2022-04-12_14-31-14.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2667_2022-04-12_14-31-14.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2667_2022-04-12_14-31-14.eeg\export-#1495_2667_2022-04-12_14-31-14.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2667_2022-04-12_14-31-14.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2667_2022-04-12_14-31-14.eeg\eegdata\eegdata.ini
# Opening all (1) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2667_2022-04-12_14-31-14.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 2 segment(s), n_samples: [12720, 974864]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2667_2022-04-12_14-31-14.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2667_2022-04-12_14-31-14.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2667_2022-04-12_14-31-14.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 206 event(s), 120 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 987584)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 206 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 147 segments: 0 (4), 0.50 (3), 00:31 (2), 01:00 (2), 01:30 ...>
# Creating RawArray with float64 data, n_channels=33, n_times=987584
#     Range : 0 ... 987583 =      0.000 ...  3857.746 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 112 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 987584 (3857.7 s), ~248.7 MB, data loaded>
# Conversion complete
# Before drop some row, shape = (987584, 34)
# After  drop some row, shape = (982208, 34)
# Setting up band-pass filter from 0.5 - 70 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 70.00 Hz
# - Upper transition bandwidth: 17.50 Hz (-6 dB cutoff frequency: 78.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=982208
#     Range : 0 ... 982207 =      0.000 ...  3836.746 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.4s
# EEG_Dataset/Export-#1495_2667_2022-04-12_14-31-14.eeg does not contain NULL value, the process will continue
# The dataframe of EEG_Dataset/Export-#1495_2667_2022-04-12_14-31-14.eeg have been saved to EEG_csv/eeg8.csv
#
# For the file:  EEG_Dataset/Export-#1495_2669_2023-11-27_11-39-39.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2669_2023-11-27_11-39-39.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2669_2023-11-27_11-39-39.eeg\export-#1495_2669_2023-11-27_11-39-39.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2669_2023-11-27_11-39-39.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1495_2669_2023-11-27_11-39-39.eeg\eegdata\eegdata.ini
# Opening all (2) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# ...
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2681_2023-09-11_09-59-42.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 288 event(s), 62 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 4689328)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 288 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 280 segments: 0 (12), 0.50 (13), 10 (12), 10 s/page (4), ...>
# Creating RawArray with float64 data, n_channels=33, n_times=4689328
#     Range : 0 ... 4689327 =      0.000 ... 18317.684 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 24 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 4689328 (18317.7 s), ~1.15 GB, data loaded>
# Conversion complete
# Before drop some row, shape = (4689328, 34)
# After  drop some row, shape = (4683952, 34)
# Setting up band-pass filter from 0.5 - 70 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 70.00 Hz
# - Upper transition bandwidth: 17.50 Hz (-6 dB cutoff frequency: 78.75 Hz)
# - Filter length: 1691 samples (6.605 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    2.4s
# Creating RawArray with float64 data, n_channels=19, n_times=4683952
#     Range : 0 ... 4683951 =      0.000 ... 18296.684 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# EEG_Dataset/Export-#1497_2681_2023-09-11_09-59-42.eeg does not contain NULL value, the process will continue
# The dataframe of EEG_Dataset/Export-#1497_2681_2023-09-11_09-59-42.eeg have been saved to EEG_csv/eeg18.csv
#
# For the file:  EEG_Dataset/Export-#1497_2682_2023-11-22_00-32-49.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\export-#1497_2682_2023-11-22_00-32-49.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\eegdata\eegdata.ini
# Opening all (5) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [1595413]
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\eegdata\eegdata-1.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [1600000]
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\eegdata\eegdata-2.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [1600000]
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\eegdata\eegdata-3.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [1600000]
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\eegdata\eegdata-4.rda
# Reading .rda segments...
# Read 1 segment(s), n_samples: [84683]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2682_2023-11-22_00-32-49.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 60 event(s), 26 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 6480096)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 60 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 59 segments: 0 (3), 0.50 (3), 10 (3), 10 s/page (1), 10-20 ...>
# Creating RawArray with float64 data, n_channels=33, n_times=6480096
#     Range : 0 ... 6480095 =      0.000 ... 25312.871 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# Raw: <RawArray | 33 x 6480096 (25312.9 s), ~1.59 GB, data loaded>
# Conversion complete
# Before drop some row, shape = (6480096, 34)
# After  drop some row, shape = (6474720, 34)
# Setting up band-pass filter from 0.5 - 70 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 70.00 Hz
# - Upper transition bandwidth: 17.50 Hz (-6 dB cutoff frequency: 78.75 Hz)
# - Filter length: 1691 samples (6.605 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    2.8s
# Creating RawArray with float64 data, n_channels=19, n_times=6474720
#     Range : 0 ... 6474719 =      0.000 ... 25291.871 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# EEG_Dataset/Export-#1497_2682_2023-11-22_00-32-49.eeg does not contain NULL value, the process will continue
# The dataframe of EEG_Dataset/Export-#1497_2682_2023-11-22_00-32-49.eeg have been saved to EEG_csv/eeg19.csv
#
# For the file:  EEG_Dataset/Export-#1497_2683_2022-09-09_11-56-39.eeg
# Start to import c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2683_2022-09-09_11-56-39.eeg
# Checking necessary files...
# Found .sdy at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2683_2022-09-09_11-56-39.eeg\export-#1497_2683_2022-09-09_11-56-39.sdy
# Checking the content of c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2683_2022-09-09_11-56-39.eeg\eegdata
# Found EEG header at c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2683_2022-09-09_11-56-39.eeg\eegdata\eegdata.ini
# Opening all (1) .rda file(s)
# Checking optional files...
# Checking electrode placement file...
# WARNING: Multiple electrode palcement files found
# Checking event database...
# Event database ok
# Reading Compumedics header (.sdy) file
# Compumedics header loaded
# 33 channel(s): ['EMG2', 'ECGL', 'ECGR', 'HV', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7', 'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz', 'T1', 'T2', 'EOGL', 'EOGR', 'EMG1', 'Fp1', 'Fp2', 'F3', 'F4', '29', '30', '31', '32', 'SpO2']
# Sampling frequency: 256.0Hz
# Compumedics header file ok
# Reading EEG header (eegdata.ini) file...
# EEG header file loaded
# Maximum 1600000 samples for each .rda file
# 33 channels in each .rda file
# EEG header file ok
# Consistency check is skipped
# Reading .rda file(s)...
# Opening .rda file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2683_2022-09-09_11-56-39.eeg\eegdata\eegdata-0.rda
# Reading .rda segments...
# Read 2 segment(s), n_samples: [3056, 491792]
# .rda files loaded lazily
# Reading electrode placement file(s)...
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2683_2022-09-09_11-56-39.eeg\electrodeplacements\10-20 with source derivation.xml
# Dropping location of channel 'A1' (Not in .sdy)
# Dropping location of channel 'A2' (Not in .sdy)
# Dropping location of channel 'ECG' (Not in .sdy)
# Placement processing complete: 21 channels
# Reading electrode placement file: c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2683_2022-09-09_11-56-39.eeg\electrodeplacements\10-20.xml
# Dropping location of channel '20' (Not in .sdy)
# Placement processing complete: 32 channels
# Electrode placement file(s) done
# Reading event database...
# Parsing event database c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\EEG_Dataset\Export-#1497_2683_2022-09-09_11-56-39.eeg\eegstudydb.mdb
# Database parsing ok
# Processing EEGEvent
# Found 171 event(s), 116 unique name(s)
# Processing EEGEventCategory
# Found 5 event categories
# Event database done
# Import complete
# Converting Compumedics files into MNE objects
# Loading all .rda segments...
# Loaded .rda segments, shape = (33, 494848)
# Attempting to link electrode placement file
# Making standard digital montage (standard_1020)
# Digital montage ok
# Deducting channel types...
# WARNING: Cannot deduct the channel type of HV, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T1, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of T2, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 29, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 30, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 31, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of 32, it is set to 'misc' type
# WARNING: Cannot deduct the channel type of SpO2, it is set to 'misc' type
# Channel type deduction complete
# Linking events...
# All 171 event(s) will be linked
# Event processing ok
# Constructing MNE objects...
# Info: <Info | 7 non-empty values
#  bads: []
#  ch_names: EMG2, ECGL, ECGR, HV, C3, C4, P3, P4, O1, O2, F7, F8, T3, T4, ...
#  chs: 2 EMG, 2 ECG, 8 misc, 19 EEG, 2 EOG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 128.0 Hz
#  meas_date: unspecified
#  nchan: 33
#  projs: []
#  sfreq: 256.0 Hz
# >
# Annotation: <Annotations | 143 segments: 0 (3), 0.50 (8), 1 (3), 10 (6), 10 s/page ...>
# Creating RawArray with float64 data, n_channels=33, n_times=494848
#     Range : 0 ... 494847 =      0.000 ...  1932.996 secs
# Ready.
# Location for this channel is unknown; consider calling set_montage() after adding new reference channels if needed. Applying a montage will only set locations of channels that exist at the time it is applied.
# c:\Users\xinju\Desktop\Python_Jupyter\Y3_Sem2_Thesis_XAI\ummc_db_util.py:294: RuntimeWarning: Omitted 126 annotation(s) that were outside data range.
#   raw.set_annotations(ann)
# Raw: <RawArray | 33 x 494848 (1933.0 s), ~124.6 MB, data loaded>
# Conversion complete
# Before drop some row, shape = (494848, 34)
# After  drop some row, shape = (489472, 34)
# Setting up band-pass filter from 0.5 - 70 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 70.00 Hz
# - Upper transition bandwidth: 17.50 Hz (-6 dB cutoff frequency: 78.75 Hz)
# - Filter length: 1691 samples (6.605 s)
#
# Creating RawArray with float64 data, n_channels=19, n_times=489472
#     Range : 0 ... 489471 =      0.000 ...  1911.996 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.3s
# EEG_Dataset/Export-#1497_2683_2022-09-09_11-56-39.eeg does not contain NULL value, the process will continue
# The dataframe of EEG_Dataset/Export-#1497_2683_2022-09-09_11-56-39.eeg have been saved to EEG_csv/eeg20.csv
#
# CPU times: total: 14min 23s
# Wall time: 25min 58s
